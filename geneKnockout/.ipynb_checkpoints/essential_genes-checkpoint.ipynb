# %%
import os
import json
import pandas as pd
from cobra.io import read_sbml_model
from cobra.flux_analysis import single_gene_deletion
from collections import defaultdict

# %%
microbes_list = pd.read_csv("/home/javad/pyprojects/MO_GEMs_Score/GraphRAG/data/subsystem_scores_per_microbe.csv")

# %%
microbes_list.head()
# Out:
#                                      Pathways  \
# 0                    Transport, extracellular
# 1                           Lysine metabolism
# 2              Glycerophospholipid metabolism
# 3                        Fatty acid synthesis
# 4  Valine, leucine, and isoleucine metabolism
#
#    Ruminococcus_champanellensis_18P13  \
# 0                        1.032208e+01
# 1                        1.401583e-01
# 2                        1.057417e+01
# 3                        1.006081e-15
# 4                        0.000000e+00
#
#    Bifidobacterium_longum_longum_ATCC_55813  Veillonella_parvula_Te3_DSM_2008  \
# 0                              3.696395e+01                         15.825589
# 1                              1.438989e-01                         39.169100
# 2                              6.926791e+00                         14.544699
# 3                              9.131037e-18                          0.034666
# 4                              5.416836e+01                         31.550394
#
#    Mycoplasma_hominis_ATCC_23114  Bifidobacterium_longum_longum_CCUG_52486  \
# 0                   6.357982e-02                              3.577133e+01
# 1                   3.826223e-21                              1.377064e-01
# 2                   1.179105e+01                              8.337046e+00
# 3                   3.329664e-03                              3.330634e-17
# 4                   2.724817e-03                              5.232436e+01
#
#    Bacteroides_xylanisolvens_XB1A  Acidaminococcus_intestini_RyC_MR95  \
# 0                       23.130707                           30.241773
# 1                       39.533871                           89.467853
# 2                        3.652043                           15.031776
# 3                        0.063624                            0.065502
# 4                       41.385394                           49.266963
#
#    Clostridium_sporogenes_ATCC_15579  \
# 0                          30.582074
# 1                           0.123237
# 2                           8.403231
# 3                           6.062487
# 4                           0.095350
#
#    Bifidobacterium_longum_infantis_ATCC_15697  ...  \
# 0                                1.324477e+01  ...
# 1                                9.391875e-02  ...
# 2                                8.211440e+00  ...
# 3                                2.523718e-18  ...
# 4                                5.753625e+01  ...
#
#    Desulfovibrio_piger_ATCC_29098  Faecalibacterium_prausnitzii_L2_6  \
# 0                       21.976751                          10.897947
# 1                      246.828341                           0.119688
# 2                       10.778320                          12.144894
# 3                        0.032385                           5.064725
# 4                       53.123013                          43.929376
#
#    Bacteroides_cellulosilyticus_DSM_14838  \
# 0                               60.063672
# 1                               48.214516
# 2                                4.516368
# 3                                0.301306
# 4                               43.668153
#
#    Methanobrevibacter_smithii_ATCC_35061  Anaerostipes_hadrus_DSM_3319  \
# 0                              14.837152                     15.394125
# 1                               0.057459                    159.437902
# 2                              17.271701                      8.826568
# 3                               6.475962                      6.142270
# 4                              56.000392                     33.673923
#
#    Haemophilus_parainfluenzae_T3T1  Clostridium_bolteae_ATCC_BAA_613  \
# 0                        18.172340                      2.368765e+01
# 1                        77.697953                      4.504619e+01
# 2                         8.647526                      1.456048e+01
# 3                         0.013349                      1.884192e-15
# 4                        41.803304                      5.301228e+01
#
#    Bifidobacterium_longum_E18  Bifidobacterium_longum_longum_JDM301  \
# 0                   31.928995                             12.570073
# 1                    0.007649                              0.095898
# 2                    5.744228                              4.251632
# 3                    0.069601                              0.039459
# 4                   25.687592                             50.359916
#
#    Eubacterium_eligens_ATCC_27750
# 0                       24.107475
# 1                        0.154211
# 2                       12.549194
# 3                        5.632010
# 4                       46.830264
#
# [5 rows x 77 columns]

# %%
# list(microbes_list['Pathways'])

# %%
microbes = list(microbes_list.keys())

AGORA_baseURL = "https://www.vmh.life/files/reconstructions/AGORA/1.03/reconstructions/sbml/"

output_dir = "agora_models"
os.makedirs(output_dir, exist_ok=True)

#Download XML files
for microbe in microbes:
    filename = f"{microbe}.xml"
    url = AGORA_baseURL + filename
    output_path = os.path.join(output_dir, filename)
    try:
        response = requests.get(url)
        response.raise_for_status()
        with open(output_path, "wb") as f:
            f.write(response.content)
        print(f"Downloaded: {filename}")
    except requests.HTTPError as e:
        print(f"Failed to download {filename}: {e}")
# Out:
# Failed to download Pathways.xml: 404 Client Error: Not Found for url: https://www.vmh.life/files/reconstructions/AGORA/1.03/reconstructions/sbml/Pathways.xml
# Downloaded: Ruminococcus_champanellensis_18P13.xml
# Downloaded: Bifidobacterium_longum_longum_ATCC_55813.xml
# Downloaded: Veillonella_parvula_Te3_DSM_2008.xml
# Downloaded: Mycoplasma_hominis_ATCC_23114.xml
# Downloaded: Bifidobacterium_longum_longum_CCUG_52486.xml
# Downloaded: Bacteroides_xylanisolvens_XB1A.xml
# Downloaded: Acidaminococcus_intestini_RyC_MR95.xml
# Downloaded: Clostridium_sporogenes_ATCC_15579.xml
# Downloaded: Bifidobacterium_longum_infantis_ATCC_15697.xml
# Downloaded: Lactobacillus_ruminis_ATCC_25644.xml
# Downloaded: Campylobacter_hominis_ATCC_BAA_381.xml
# Downloaded: Bacteroides_dorei_DSM_17855.xml
# Downloaded: Coprococcus_catus_GD_7.xml
# Downloaded: Bifidobacterium_bifidum_PRL2010.xml
# Downloaded: Ruminococcus_obeum_A2_162.xml
# Downloaded: Bacteroides_vulgatus_ATCC_8482.xml
# Downloaded: Bacteroides_ovatus_SD_CMC_3f.xml
# Downloaded: Flavonifractor_plautii_ATCC_29863.xml
# Downloaded: Bifidobacterium_longum_DJO10A.xml
# Downloaded: Bifidobacterium_longum_NCC2705.xml
# Downloaded: Megasphaera_elsdenii_DSM_20460.xml
# Downloaded: Bifidobacterium_bifidum_NCIMB_41171.xml
# Downloaded: Bacteroides_fragilis_3_1_12.xml
# Downloaded: Adlercreutzia_equolifaciens_DSM_19450.xml
# Downloaded: Staphylococcus_hominis_subsp_hominis_C80.xml
# Downloaded: Bacteroides_xylanisolvens_SD_CC_1b.xml
# Downloaded: Prevotella_ruminicola_23.xml
# Downloaded: Bifidobacterium_longum_infantis_157F_NC.xml
# Downloaded: Bacteroides_fragilis_YCH46.xml
# Downloaded: Bacteroides_fragilis_NCTC_9343.xml
# Downloaded: Akkermansia_muciniphila_ATCC_BAA_835.xml
# Downloaded: Bacteroides_thetaiotaomicron_VPI_5482.xml
# Downloaded: Bifidobacterium_bifidum_S17.xml
# Downloaded: Bifidobacterium_adolescentis_ATCC_15703.xml
# Downloaded: Bacteroides_fragilis_638R.xml
# Downloaded: Alistipes_shahii_WAL_8301.xml
# Downloaded: Streptococcus_pneumoniae_G54.xml
# Downloaded: Bacteroides_caccae_ATCC_43185.xml
# Downloaded: Ruminococcus_torques_ATCC_27756.xml
# Downloaded: Klebsiella_pneumoniae_pneumoniae_MGH78578.xml
# Downloaded: Collinsella_aerofaciens_ATCC_25986.xml
# Downloaded: Megamonas_hypermegale_ART12_1.xml
# Downloaded: Bifidobacterium_longum_longum_JCM_1217.xml
# Downloaded: Roseburia_hominis_A2_183.xml
# Downloaded: Blautia_obeum_ATCC_29174.xml
# Downloaded: Ruminococcus_bicirculans_80_3.xml
# Downloaded: Acidaminococcus_fermentans_DSM_20731.xml
# Downloaded: Odoribacter_splanchnicus_1651_6_DSM_20712.xml
# Downloaded: Faecalibacterium_prausnitzii_SL3_3.xml
# Downloaded: Bifidobacterium_pseudocatenulatum_DSM_20438.xml
# Downloaded: Lactococcus_lactis_subsp_lactis_Il1403.xml
# Downloaded: Roseburia_intestinalis_L1_82.xml
# Downloaded: Bifidobacterium_bifidum_BGN4.xml
# Downloaded: Eubacterium_cylindroides_T2_87.xml
# Downloaded: Parabacteroides_distasonis_ATCC_8503.xml
# Downloaded: Alistipes_finegoldii_DSM_17242.xml
# Downloaded: Ruminococcus_torques_L2_14.xml
# Downloaded: Eubacterium_hallii_L2_7.xml
# Downloaded: Bacteroides_ovatus_ATCC_8483.xml
# Downloaded: Bifidobacterium_longum_longum_BBMN68.xml
# Downloaded: Faecalibacterium_prausnitzii_M21_2.xml
# Downloaded: Streptococcus_thermophilus_LMG_18311.xml
# Downloaded: Bacteroides_ovatus_SD_CC_2a.xml
# Downloaded: Eggerthella_lenta_DSM_2243.xml
# Downloaded: Eubacterium_hallii_DSM_3353.xml
# Downloaded: Faecalibacterium_prausnitzii_A2_165.xml
# Downloaded: Desulfovibrio_piger_ATCC_29098.xml
# Downloaded: Faecalibacterium_prausnitzii_L2_6.xml
# Downloaded: Bacteroides_cellulosilyticus_DSM_14838.xml
# Downloaded: Methanobrevibacter_smithii_ATCC_35061.xml
# Downloaded: Anaerostipes_hadrus_DSM_3319.xml
# Downloaded: Haemophilus_parainfluenzae_T3T1.xml
# Downloaded: Clostridium_bolteae_ATCC_BAA_613.xml
# Downloaded: Bifidobacterium_longum_E18.xml
# Downloaded: Bifidobacterium_longum_longum_JDM301.xml
# Downloaded: Eubacterium_eligens_ATCC_27750.xml

# %% [markdown]
# ## Identify Essential genes
#
# AND save them into  a JSON file

# %%
#load rxn subsystem info
with open("/home/javad/pyprojects/MO_GEMs_Score/GraphRAG/data/reaction_info.json", "r") as f:
    reaction_info = json.load(f)

# %%
target_subsystems = {
    "NAD metabolism",                      # NAD biosynthesis & salvage
    "CoA synthesis",                      # Coenzyme A biosynthesis
    "Folate metabolism",                  # Folic acid (vitamin B9)
    "Thiamine metabolism",                # Vitamin B1
    "Vitamin B2 metabolism",              # Riboflavin
    "Vitamin B6 metabolism",              # Pyridoxal phosphate
    "Vitamin B12 metabolism",             # Cobalamin
    "Biotin metabolism",                  # Biotin (vitamin B7)
    "Fatty acid synthesis",               # Lipid membrane precursors
    "Cell wall biosynthesis",            # Peptidoglycan biosynthesis
    "Lipopolysaccharide biosynthesis",    # LPS barrier in Gram-negative bacteria
    "Energy metabolism",                 # General redox/ATP balance
    "Oxidative phosphorylation",          # NADH >> ATP production
    "Citric acid cycle",                 # Central to energy generation
    "Glycolysis/gluconeogenesis"         # Basic metabolic flux
    }

# %%
def assign_fluxes(model, medium_type: str, diet_data: pd.DataFrame, oxygen_status: str):
      
    if medium_type not in ["fat", "High fiber diet", "rich"]:
        raise ValueError("Invalid medium type. Choose 'High fat diet', 'High fiber diet', or 'rich'.")
    if oxygen_status not in ["present", "absent"]:
        raise ValueError("Invalid oxygen status. Choose 'present' or 'absent'.")

    o2Rxn = "EX_o2(e)"  
    if o2Rxn in model.reactions:
        if oxygen_status == "present":
            model.reactions.get_by_id(o2Rxn).lower_bound = -10
        elif oxygen_status == "absent":
            model.reactions.get_by_id(o2Rxn).lower_bound = 0

    if medium_type == "rich":
        #open all fluxes
        for rxn in model.exchanges:
            # if "EX_" in reaction.id:  #exchange rxns start with "EX_"
            rxn.lower_bound = -1000
            rxn.upper_bound = 1000
    else:
        #reset all exchange rxn lower bounds to 0
        for rxn in model.exchanges:
            # if "EX_" in rxn.id:  
            rxn.lower_bound = 0
        
        #assign fluxes 
        noRxns = 0
        skippedRxns = 0
        for _, row in diet_data.iterrows():
            rxn_id = row["Exchange rxn ID"]
            flux_value = row[medium_type]
            
            #check if the rxn exists in the model
            if rxn_id in model.reactions:
                rxn = model.reactions.get_by_id(rxn_id)
                rxn.lower_bound = -flux_value
                rxn.upper_bound = 1000
                noRxns += 1
            else:
                #log rxns not found
                skippedRxns += 1
                # print(f"Reaction {rxn_id} not found in the model. Skipping.")

    print(f"Total added fluxes: {noRxns}")

# %%
diet_data = pd.read_excel("/home/javad/pyprojects/MO_GEMs_Score/graphNN/data/medium_list.xlsx", sheet_name="Table_1")

# %%
import os
import json
from collections import defaultdict
from cobra.io import read_sbml_model
from cobra.flux_analysis import single_gene_deletion
from multiprocessing import cpu_count
from tqdm import tqdm

# %%
model_dir = "agora_models"
reaction_info_path = "reaction_info.json"
output_json = "essential_drug_target_genes.json"
diet_type = "High fiber diet"
o2_status = "absent"

relevant_rxns = {rxn_id for rxn_id, info in reaction_info.items()
            if info.get("Subsystem") in target_subsystems}

results = {}
readable_lines = []
# --- Process each model ---
i=0
for filename in os.listdir(model_dir):
    # i+=1
    # if i==4:
    #     break
    if not filename.endswith(".xml"):
        continue

    model_name = filename.replace(".xml", "")
    model_path = os.path.join(model_dir, filename)
    print(f"Processing: {model_name}")

    try:
        model = read_sbml_model(model_path)
        assign_fluxes(model, diet_type, diet_data, o2_status)
        

        gene_to_reactions = defaultdict(list)
        for rxn_id in relevant_rxns:
            if rxn_id in model.reactions:
                rxn = model.reactions.get_by_id(rxn_id)
                
                for gene in rxn.genes:
                    gene_to_reactions[gene.id].append({
                        "reaction": rxn.id,
                        "subsystem": reaction_info.get(rxn.id, {}).get("Subsystem", "Unknown")
                    })
        # print('ppp')
        # print(gene_to_reactions)
        if not gene_to_reactions:
            print("  No relevant genes found.")
            continue

        # wild-type growth
        wild_type_growth = model.slim_optimize()
        if wild_type_growth is None or wild_type_growth < 1e-6:
            print("  No growth in wild-type. Skipping.")
            continue
        threshold = 0.05 * wild_type_growth

        # gene knockouts only for relevant genes
        gene_list = list(gene_to_reactions.keys())

        gene_id_list = list(gene_to_reactions.keys())
        # print(gene_id_list)
        gene_objects = [model.genes.get_by_id(g) for g in gene_id_list]
        gene_index_to_id = {i: gene.id for i, gene in enumerate(gene_objects)}
        
        # Run deletion
        deletion_results = single_gene_deletion(model, gene_list=gene_objects)
        
        essential_gene_indices = deletion_results[deletion_results["growth"] < threshold].index.tolist()
        # print(essential_gene_indices)
        #Convert back to real gene IDs
        essential_genes = [gene_index_to_id[i] for i in essential_gene_indices]
        # print('xxx')
        # print(essential_genes)

        model_essentials = []
        readable_lines.append(f"{model_name}")
        for gene in essential_genes:
            reactions = gene_to_reactions[gene]
            model_essentials.append({"gene": gene, "reactions": reactions})

            rxn_str = ", ".join(f"{r['reaction']} ({r['subsystem']})" for r in reactions)
            readable_lines.append(f"  {gene} >> {rxn_str}")

        if model_essentials:
            results[model_name] = model_essentials
        print(f"  {len(model_essentials)} essential genes found.")

    except Exception as e:
        print(f"  Error in {model_name}: {e}")
# Out:
# Processing: Streptococcus_pneumoniae_G54
# Total added fluxes: 91
#   31 essential genes found.
# Processing: Bifidobacterium_longum_E18
# Total added fluxes: 73
# Process ForkPoolWorker-5135:
# Process ForkPoolWorker-5134:
# Exception ignored in: <function _releaseLock at 0x7e3c6c19c1f0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/logging/__init__.py", line 228, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt:
# Process ForkPoolWorker-5132:
# Process ForkPoolWorker-5133:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Process ForkPoolWorker-5137:
# Process ForkPoolWorker-5138:
# Process ForkPoolWorker-5139:
# Process ForkPoolWorker-5141:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[77], line 62
#      59 gene_index_to_id = {i: gene.id for i, gene in enumerate(gene_objects)}
#      61 # Run deletion
# ---> 62 deletion_results = single_gene_deletion(model, gene_list=gene_objects)
#      64 essential_gene_indices = deletion_results[deletion_results["growth"] < threshold].index.tolist()
#      65 # print(essential_gene_indices)
#      66 #Convert back to real gene IDs
#
# File /new/benpyenv/lib/python3.10/site-packages/cobra/flux_analysis/deletion.py:393, in single_gene_deletion(model, gene_list, method, solution, processes, **kwargs)
#     349 def single_gene_deletion(
#     350     model: Model,
#     351     gene_list: Optional[List[Union[Gene, str]]] = None,
#    (...)
#     355     **kwargs,
#     356 ) -> pd.DataFrame:
#     357     """Knock out each gene from `gene_list`.
#     358
#     359     Parameters
#    (...)
#     391
#     392     """
# --> 393     return _multi_deletion(
#     394         model,
#     395         "gene",
#     396         element_lists=_element_lists(model.genes, gene_list),
#     397         method=method,
#     398         solution=solution,
#     399         processes=processes,
#     400         **kwargs,
#     401     )
#
# File /new/benpyenv/lib/python3.10/site-packages/cobra/flux_analysis/deletion.py:232, in _multi_deletion(model, entity, element_lists, method, solution, processes, **kwargs)
#     226     worker = {
#     227         "gene": _gene_deletion_worker,
#     228         "reaction": _reaction_deletion_worker,
#     229     }[entity]
#     230     chunk_size = len(args) // processes
# --> 232     with ProcessPool(
#     233         processes, initializer=_init_worker, initargs=(model,)
#     234     ) as pool:
#     235         results = extract_knockout_results(
#     236             pool.imap_unordered(worker, args, chunksize=chunk_size)
#     237         )
#     238 else:
#
# File /new/benpyenv/lib/python3.10/site-packages/cobra/util/process_pool.py:85, in ProcessPool.__exit__(self, exc_type, exc_val, exc_tb)
#      83 try:
#      84     self._pool.close()
# ---> 85     self._pool.join()
#      86 finally:
#      87     self._clean_up()
#
# File /usr/lib/python3.10/multiprocessing/pool.py:665, in Pool.join(self)
#     663 elif self._state not in (CLOSE, TERMINATE):
#     664     raise ValueError("In unknown state")
# --> 665 self._worker_handler.join()
#     666 self._task_handler.join()
#     667 self._result_handler.join()
#
# File /usr/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:
# Process ForkPoolWorker-5142:
# Process ForkPoolWorker-5140:
# Process ForkPoolWorker-5144:
# Process ForkPoolWorker-5143:
# Process ForkPoolWorker-5146:
# Process ForkPoolWorker-5145:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Exception ignored in: <function Socket.__del__ at 0x7e3c6c0f3910>
# Traceback (most recent call last):
#   File "/new/benpyenv/lib/python3.10/site-packages/zmq/sugar/socket.py", line 175, in __del__
#     def __del__(self):
# KeyboardInterrupt:
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "/new/benpyenv/lib/python3.10/site-packages/ipykernel/iostream.py", line 609, in flush
#     if not evt.wait(self.flush_timeout):
#   File "/usr/lib/python3.10/threading.py", line 607, in wait
#     signaled = self._cond.wait(timeout)
#   File "/usr/lib/python3.10/threading.py", line 324, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt:
# Process ForkPoolWorker-5136:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
with open(output_json, "w") as f:
    json.dump(results, f, indent=2)


print(f"\n✅ Saved structured JSON to: {output_json}")
# Out:
# ✅ Saved structured JSON to: essential_drug_target_genes.json

# %% [markdown]
# ## Read json file including list of essential genes for every microbe under high fiber diet
#
# Get corresponding KO for each essential gene from VMH
#
# Retrieve GenBank files for each microbe
#
# Use KO functionalities to find protein seqs for essential genes

# %%
import os
import json
import requests
import time
import gzip
import pandas as pd
import time
from tqdm import tqdm
from Bio import Entrez, SeqIO

Entrez.email = "javadamn@gmail.com"

# %%
with open("essential_drug_target_genes.json") as f:
    microbes_ess_genes = json.load(f)

# %%
unique_genes = set()
for gene_list in microbes_ess_genes.values():
    for entry in gene_list:
        unique_genes.add(entry["gene"])

# %%
len(unique_genes)
# Out:
# 2463

# %%
def fetch_gene_annotations(gene_id):
    url = f"https://www.vmh.life/_api/microbegenereactions/{gene_id}/"
    # print(url)
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.json()
    except Exception as e:
        print(f"Error fetching gene {gene_id}: {e}")
        return None

# %%
all_gene_annotations = {}
seen_genes = set()
records = []

unique_genes = {}
for model, gene_entries in microbes_ess_genes.items():
    for entry in gene_entries:
        gene_id = entry["gene"]
        if gene_id not in seen_genes:
            seen_genes.add(gene_id)
            unique_genes[gene_id] = model  
print(f"Number of unique gene IDs: {len(unique_genes)}")

# i = 0
for gene_id in tqdm(unique_genes, desc="Fetching gene annotations"):
    # i += 1
    # if i > 5:
    #     break
    annotation = fetch_gene_annotations(gene_id)
    if annotation:
        all_gene_annotations[gene_id] = annotation
        results = annotation.get("results", [])
        
        for item in results:
            kegg_orthology = item.get("keggorthology", None)
            if kegg_orthology:
                kegg_orthology = kegg_orthology.strip().split()  #split into multiple KEGG orthologies if needed
            ecnumber = item.get("ecnumber", None)
            subsystem = item.get("subsystem", None)
            description = item.get("description", None)
            isHuman = item.get("isHuman", None)
            seed = item.get("seed", None)
            
            #None if not available
            if kegg_orthology:
                for ko in kegg_orthology:
                    records.append({
                        "model": unique_genes[gene_id],
                        "gene_id": gene_id,
                        "kegg_orthology": ko,
                        "ecnumber": ecnumber,
                        "subsystem": subsystem,
                        "description": description,
                        "isHuman": isHuman,
                        "seedID": seed
                                        })
            else:
                records.append({
                            "model": unique_genes[gene_id],
                            "gene_id": gene_id,
                            "kegg_orthology": None,
                            "ecnumber": ecnumber,
                            "subsystem": subsystem,
                            "description": description,
                            "isHuman": isHuman,
                            "seedID": seed
                                                        })
    else:
        records.append({
                        "model": unique_genes[gene_id],
                        "gene_id": gene_id,
                        "kegg_orthology": None,
                        "ecnumber": None,
                        "subsystem": None,
                        "description": None,
                        "isHuman": None,
                        "seedID": None
                                                                })
    time.sleep(0.3)

gene_df = pd.DataFrame(records)
# Out:
# Number of unique gene IDs: 2463
# Fetching gene annotations: 100%|████████████| 2463/2463 [50:33<00:00,  1.23s/it]

# %%
# gene_df['gene_id']== '709991.5.peg.2285'

# %%
strain_accession_mapping = pd.read_csv("xml_w_genome_accession.csv")

# %%
merged_df = gene_df.merge(strain_accession_mapping[['strain_name', 'genome_accession']], 
                          how='left', 
                          left_on='model', 
                          right_on='strain_name')

merged_df.drop(columns=['strain_name'], inplace=True)
# merged_df.head()
# Out:
#                           model          gene_id kegg_orthology  ecnumber  \
# 0  Streptococcus_pneumoniae_G54  g.1878.peg.1024           None      None
# 1  Streptococcus_pneumoniae_G54  g.1878.peg.1024         K00605  2.1.2.10
# 2  Streptococcus_pneumoniae_G54  g.1878.peg.1024         K00281  2.1.2.10
# 3  Streptococcus_pneumoniae_G54  g.1878.peg.1024         K00282  2.1.2.10
# 4  Streptococcus_pneumoniae_G54  g.1878.peg.1024         K00283  2.1.2.10
#
#                                            subsystem  \
# 0                                  Folate metabolism
# 1  Glycine, serine, alanine and threonine metabolism
# 2                                  Folate metabolism
# 3                                  Folate metabolism
# 4                                  Folate metabolism
#
#                 description  isHuman    seedID genome_accession
# 0    Aminomethyltransferase    False  rxn01652  GCF_000019825.1
# 1  Glycine cleavage complex    False  rxn06600  GCF_000019825.1
# 2   Glycine Cleavage System    False  rxn00908  GCF_000019825.1
# 3   Glycine Cleavage System    False  rxn00908  GCF_000019825.1
# 4   Glycine Cleavage System    False  rxn00908  GCF_000019825.1

# %%
merged_df = gene_df.merge(strain_accession_mapping[['strain_name', 'ncbiid']], 
                          how='left', 
                          left_on='model', 
                          right_on='strain_name')

merged_df.drop(columns=['strain_name'], inplace=True)
# merged_df.head()
# Out:
#                           model          gene_id kegg_orthology  ecnumber  \
# 0  Streptococcus_pneumoniae_G54  g.1878.peg.1024           None      None
# 1  Streptococcus_pneumoniae_G54  g.1878.peg.1024         K00605  2.1.2.10
# 2  Streptococcus_pneumoniae_G54  g.1878.peg.1024         K00281  2.1.2.10
# 3  Streptococcus_pneumoniae_G54  g.1878.peg.1024         K00282  2.1.2.10
# 4  Streptococcus_pneumoniae_G54  g.1878.peg.1024         K00283  2.1.2.10
#
#                                            subsystem  \
# 0                                  Folate metabolism
# 1  Glycine, serine, alanine and threonine metabolism
# 2                                  Folate metabolism
# 3                                  Folate metabolism
# 4                                  Folate metabolism
#
#                 description  isHuman    seedID genome_accession  ncbiid
# 0    Aminomethyltransferase    False  rxn01652  GCF_000019825.1  512566
# 1  Glycine cleavage complex    False  rxn06600  GCF_000019825.1  512566
# 2   Glycine Cleavage System    False  rxn00908  GCF_000019825.1  512566
# 3   Glycine Cleavage System    False  rxn00908  GCF_000019825.1  512566
# 4   Glycine Cleavage System    False  rxn00908  GCF_000019825.1  512566

# %%
gene_df = merged_df

# %%
gene_df.to_csv('gene_df_info.csv', index=False)

print(f"Saved structured dataFrame")
# Out:
# Saved structured dataFrame

# %% [markdown]
# ## Download GenBank files with genome accession ids

# %%
import pandas as pd
from Bio import Entrez, SeqIO
import os
import requests
import gzip
import shutil

Entrez.email = "javadamn@gmail.com"
output_dir = "/GenBank_files"
# os.makedirs(output_dir, exist_ok=True)

# %%
gene_df = pd.read_csv("gene_df_info.csv")

# %%
gene_df = gene_df.drop_duplicates(subset="genome_accession")

# %%
accessions = gene_df['genome_accession'].dropna().unique()

# %%
accessions = [
    ("GCF_000019825.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/019/825/GCF_000019825.1_ASM1982v1/GCF_000019825.1_ASM1982v1_genomic.gbff.gz"),
    ("GCF_000497735.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/497/735/GCF_000497735.1_BLONGv1.0/GCF_000497735.1_BLONGv1.0_genomic.gbff.gz"),
    ("GCF_000024945.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/024/945/GCF_000024945.1_ASM2494v1/GCF_000024945.1_ASM2494v1_genomic.gbff.gz"),
    ("GCA_949495995.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/949/495/995/GCA_949495995.1_extra-SRR8581395.6_1677803352/GCA_949495995.1_extra-SRR8581395.6_1677803352_genomic.gbff.gz"),
    ("GCF_003010495.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003/010/495/GCF_003010495.1_ASM301049v1/GCF_003010495.1_ASM301049v1_genomic.gbff.gz"),
    ("GCF_000007525.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/007/525/GCF_000007525.1_ASM752v1/GCF_000007525.1_ASM752v1_genomic.gbff.gz"),
    ("GCF_000157015.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/157/015/GCF_000157015.1_ASM15701v1/GCF_000157015.1_ASM15701v1_genomic.gbff.gz"),
    ("GCA_042848235.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/042/848/235/GCA_042848235.1_ASM4284823v1/GCA_042848235.1_ASM4284823v1_genomic.gbff.gz"),
    ("GCF_020736405.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/020/736/405/GCF_020736405.1_ASM2073640v1/GCF_020736405.1_ASM2073640v1_genomic.gbff.gz"),
    ("GCF_000025925.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/025/925/GCF_000025925.1_ASM2592v1/GCF_000025925.1_ASM2592v1_genomic.gbff.gz"),
    ("GCF_000225345.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/225/345/GCF_000225345.1_ASM22534v1/GCF_000225345.1_ASM22534v1_genomic.gbff.gz"),
    ("GCF_020735645.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/020/735/645/GCF_020735645.1_ASM2073564v1/GCF_020735645.1_ASM2073564v1_genomic.gbff.gz"),
    ("GCF_000092325.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/092/325/GCF_000092325.1_ASM9232v1/GCF_000092325.1_ASM9232v1_genomic.gbff.gz"),
    ("GCF_048164435.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/048/164/435/GCF_048164435.1_ASM4816443v1/GCF_048164435.1_ASM4816443v1_genomic.gbff.gz"),
    ("GCF_000239295.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/239/295/GCF_000239295.1_ASM23929v1/GCF_000239295.1_ASM23929v1_genomic.gbff.gz"),
    ("GCF_000017585.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/017/585/GCF_000017585.1_ASM1758v1/GCF_000017585.1_ASM1758v1_genomic.gbff.gz"),
    ("GCF_000210095.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/210/095/GCF_000210095.1_ASM21009v1/GCF_000210095.1_ASM21009v1_genomic.gbff.gz"),
    ("GCF_000155415.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/155/415/GCF_000155415.1_ASM15541v1/GCF_000155415.1_ASM15541v1_genomic.gbff.gz"),
    ("GCF_964246395.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/964/246/395/GCF_964246395.1_ASM96424639v1/GCF_964246395.1_ASM96424639v1_genomic.gbff.gz"),
    ("GCF_030296915.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/030/296/915/GCF_030296915.1_ASM3029691v1/GCF_030296915.1_ASM3029691v1_genomic.gbff.gz"),
    ("GCF_000230275.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/230/275/GCF_000230275.1_ASM23027v1/GCF_000230275.1_ASM23027v1_genomic.gbff.gz"),
    ("GCF_000173975.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/173/975/GCF_000173975.1_ASM17397v1/GCF_000173975.1_ASM17397v1_genomic.gbff.gz"),
    ("GCF_000024265.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/024/265/GCF_000024265.1_ASM2426v1/GCF_000024265.1_ASM2426v1_genomic.gbff.gz"),
    ("GCF_000155085.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/155/085/GCF_000155085.1_ASM15508v1/GCF_000155085.1_ASM15508v1_genomic.gbff.gz"),
    ("GCF_900624795.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/900/624/795/GCF_900624795.1_ASM90062479v1/GCF_900624795.1_ASM90062479v1_genomic.gbff.gz"),
    ("GCA_964240745.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/964/240/745/GCA_964240745.1_ASM96424074v1/GCA_964240745.1_ASM96424074v1_genomic.gbff.gz"),
    ("GCF_000166315.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/166/315/GCF_000166315.1_ASM16631v1/GCF_000166315.1_ASM16631v1_genomic.gbff.gz"),
    ("GCF_000210015.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/210/015/GCF_000210015.1_ASM21001v1/GCF_000210015.1_ASM21001v1_genomic.gbff.gz"),
    ("GCF_000478885.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/478/885/GCF_000478885.1_ASM47888v1/GCF_000478885.1_ASM47888v1_genomic.gbff.gz"),
    ("GCF_000209975.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/209/975/GCF_000209975.1_ASM20997v1/GCF_000209975.1_ASM20997v1_genomic.gbff.gz"),
    ("GCF_000156075.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/156/075/GCF_000156075.1_ASM15607v1/GCF_000156075.1_ASM15607v1_genomic.gbff.gz"),
    ("GCF_000156375.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/156/375/GCF_000156375.1_ASM15637v1/GCF_000156375.1_ASM15637v1_genomic.gbff.gz"),
    ("GCF_000166895.2", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/166/895/GCF_000166895.2_ASM16689v2/GCF_000166895.2_ASM16689v2_genomic.gbff.gz"),
    ("GCF_000210555.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/210/555/GCF_000210555.1_ASM21055v1/GCF_000210555.1_ASM21055v1_genomic.gbff.gz"),
    ("GCF_000154385.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/154/385/GCF_000154385.1_ASM15438v1/GCF_000154385.1_ASM15438v1_genomic.gbff.gz"),
    ("GCF_000210895.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/210/895/GCF_000210895.1_ASM21089v1/GCF_000210895.1_ASM21089v1_genomic.gbff.gz"),
    ("GCF_964260205.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/964/260/205/GCF_964260205.1_ASM96426020v1/GCF_964260205.1_ASM96426020v1_genomic.gbff.gz"),
    ("GCA_022305115.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/022/305/115/GCA_022305115.1_ASM2230511v1/GCA_022305115.1_ASM2230511v1_genomic.gbff.gz"),
    ("GCF_000164965.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/164/965/GCF_000164965.1_ASM16496v1/GCF_000164965.1_ASM16496v1_genomic.gbff.gz"),
    ("GCF_000183685.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/183/685/GCF_000183685.1_ASM18368v1/GCF_000183685.1_ASM18368v1_genomic.gbff.gz"),
    ("GCF_000209855.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/209/855/GCF_000209855.1_ASM20985v1/GCF_000209855.1_ASM20985v1_genomic.gbff.gz"),
    ("GCF_000178275.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/178/275/GCF_000178275.1_ASM17827v1/GCF_000178275.1_ASM17827v1_genomic.gbff.gz"),
    ("GCF_964259715.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/964/259/715/GCF_964259715.1_ASM96425971v1/GCF_964259715.1_ASM96425971v1_genomic.gbff.gz"),
    ("GCF_025145845.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/025/145/845/GCF_025145845.1_ASM2514584v1/GCF_025145845.1_ASM2514584v1_genomic.gbff.gz"),
    ("GCF_000169015.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/169/015/GCF_000169015.1_ASM16901v1/GCF_000169015.1_ASM16901v1_genomic.gbff.gz"),
    ("GCF_000165905.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/165/905/GCF_000165905.1_ASM16590v1/GCF_000165905.1_ASM16590v1_genomic.gbff.gz"),
    ("GCF_025147765.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/025/147/765/GCF_025147765.1_ASM2514776v1/GCF_025147765.1_ASM2514776v1_genomic.gbff.gz"),
    ("GCF_000265095.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/265/095/GCF_000265095.1_ASM26509v1/GCF_000265095.1_ASM26509v1_genomic.gbff.gz"),
    ("GCF_040095415.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/040/095/415/GCF_040095415.1_ASM4009541v1/GCF_040095415.1_ASM4009541v1_genomic.gbff.gz"),
    ("GCF_000006865.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/006/865/GCF_000006865.1_ASM686v1/GCF_000006865.1_ASM686v1_genomic.gbff.gz"),
    ("GCF_000273525.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/273/525/GCF_000273525.1_ASM27352v1/GCF_000273525.1_ASM27352v1_genomic.gbff.gz"),
    ("GCF_000146185.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/146/185/GCF_000146185.1_ASM14618v1/GCF_000146185.1_ASM14618v1_genomic.gbff.gz"),
    ("GCF_000153925.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/153/925/GCF_000153925.1_ASM15392v1/GCF_000153925.1_ASM15392v1_genomic.gbff.gz"),
    ("GCF_964250545.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/964/250/545/GCF_964250545.1_ASM96425054v1/GCF_964250545.1_ASM96425054v1_genomic.gbff.gz"),
    ("GCF_964260535.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/964/260/535/GCF_964260535.1_ASM96426053v1/GCF_964260535.1_ASM96426053v1_genomic.gbff.gz"),
    ("GCF_900445515.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/900/445/515/GCF_900445515.1_ASM90044551v1/GCF_900445515.1_ASM90044551v1_genomic.gbff.gz"),
    ("GCF_017504145.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/017/504/145/GCF_017504145.1_ASM1750414v1/GCF_017504145.1_ASM1750414v1_genomic.gbff.gz"),
    ("GCF_000003135.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/003/135/GCF_000003135.1_ASM313v1/GCF_000003135.1_ASM313v1_genomic.gbff.gz"),
    ("GCF_000154365.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/154/365/GCF_000154365.1_ASM15436v1/GCF_000154365.1_ASM15436v1_genomic.gbff.gz"),
    ("GCF_000210075.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/210/075/GCF_000210075.1_ASM21007v1/GCF_000210075.1_ASM21007v1_genomic.gbff.gz"),
    ("GCF_000154125.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/154/125/GCF_000154125.1_ASM15412v1/GCF_000154125.1_ASM15412v1_genomic.gbff.gz"),
    ("GCF_964238615.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/964/238/615/GCF_964238615.1_ASM96423861v1/GCF_964238615.1_ASM96423861v1_genomic.gbff.gz"),
    ("GCF_900624785.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/900/624/785/GCF_900624785.1_ASM90062478v1/GCF_900624785.1_ASM90062478v1_genomic.gbff.gz"),
    ("GCF_000196575.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/196/575/GCF_000196575.1_ASM19657v1/GCF_000196575.1_ASM19657v1_genomic.gbff.gz"),
    ("GCF_964239605.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/964/239/605/GCF_964239605.1_ASM96423960v1/GCF_964239605.1_ASM96423960v1_genomic.gbff.gz"),
    ("GCF_046199715.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/046/199/715/GCF_046199715.1_ASM4619971v1/GCF_046199715.1_ASM4619971v1_genomic.gbff.gz"),
    ("GCF_028743435.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/028/743/435/GCF_028743435.1_ASM2874343v1/GCF_028743435.1_ASM2874343v1_genomic.gbff.gz"),
    ("GCF_964259635.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/964/259/635/GCF_964259635.1_ASM96425963v1/GCF_964259635.1_ASM96425963v1_genomic.gbff.gz"),
    ("GCF_900537995.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/900/537/995/GCF_900537995.1_ASM90053799v1/GCF_900537995.1_ASM90053799v1_genomic.gbff.gz"),
    ("GCF_000210735.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/210/735/GCF_000210735.1_ASM21073v1/GCF_000210735.1_ASM21073v1_genomic.gbff.gz"),
    ("GCF_000210615.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/210/615/GCF_000210615.1_ASM21061v1/GCF_000210615.1_ASM21061v1_genomic.gbff.gz"),
    ("GCF_000210035.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/210/035/GCF_000210035.1_ASM21003v1/GCF_000210035.1_ASM21003v1_genomic.gbff.gz"),
    ("GCF_000011825.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/011/825/GCF_000011825.1_ASM1182v1/GCF_000011825.1_ASM1182v1_genomic.gbff.gz"),
    ("GCF_000225845.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/225/845/GCF_000225845.1_ASM22584v1/GCF_000225845.1_ASM22584v1_genomic.gbff.gz"),
    ("GCF_964260485.1", "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/964/260/485/GCF_964260485.1_ASM96426048v1/GCF_964260485.1_ASM96426048v1_genomic.gbff.gz"),
]

# %%
len(accessions)
# Out:
# 75

# %%
output_dir = "/home/javad/pyprojects/MO_GEMs_Score/GraphRAG/geneKnockout/GenBank_files"

if not os.path.exists(output_dir):
    os.makedirs(output_dir)


for accession, url in accessions:
    filename = os.path.join(output_dir, f"{accession}.gbff")
    if os.path.exists(filename):
        print(f"Skipping {accession} — file already exists.")
        continue
    
    gz_filename = filename + ".gz"
    print(f"Downloading {accession} to {gz_filename}...")
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status() 
        
        with open(gz_filename, 'wb') as f_out:
            shutil.copyfileobj(response.raw, f_out)
        
        with gzip.open(gz_filename, 'rb') as f_in, open(filename, 'wb') as f_out:
            shutil.copyfileobj(f_in, f_out)
        
        os.remove(gz_filename)
        
        print(f"Downloaded and extracted: {filename}")
    except requests.exceptions.RequestException as e:
        print(f"Failed to download {accession} from {url}: {e}")
# Out:
# Skipping GCF_000019825.1 — file already exists.
# Skipping GCF_000497735.1 — file already exists.
# Skipping GCF_000024945.1 — file already exists.
# Skipping GCA_949495995.1 — file already exists.
# Skipping GCF_003010495.1 — file already exists.
# Skipping GCF_000007525.1 — file already exists.
# Skipping GCF_000157015.1 — file already exists.
# Skipping GCA_042848235.1 — file already exists.
# Skipping GCF_020736405.1 — file already exists.
# Skipping GCF_000025925.1 — file already exists.
# Skipping GCF_000225345.1 — file already exists.
# Skipping GCF_020735645.1 — file already exists.
# Skipping GCF_000092325.1 — file already exists.
# Skipping GCF_048164435.1 — file already exists.
# Skipping GCF_000239295.1 — file already exists.
# Skipping GCF_000017585.1 — file already exists.
# Skipping GCF_000210095.1 — file already exists.
# Skipping GCF_000155415.1 — file already exists.
# Skipping GCF_964246395.1 — file already exists.
# Skipping GCF_030296915.1 — file already exists.
# Skipping GCF_000230275.1 — file already exists.
# Skipping GCF_000173975.1 — file already exists.
# Skipping GCF_000024265.1 — file already exists.
# Skipping GCF_000155085.1 — file already exists.
# Skipping GCF_900624795.1 — file already exists.
# Skipping GCA_964240745.1 — file already exists.
# Skipping GCF_000166315.1 — file already exists.
# Skipping GCF_000210015.1 — file already exists.
# Skipping GCF_000478885.1 — file already exists.
# Skipping GCF_000209975.1 — file already exists.
# Skipping GCF_000156075.1 — file already exists.
# Skipping GCF_000156375.1 — file already exists.
# Skipping GCF_000166895.2 — file already exists.
# Skipping GCF_000210555.1 — file already exists.
# Skipping GCF_000154385.1 — file already exists.
# Skipping GCF_000210895.1 — file already exists.
# Skipping GCF_964260205.1 — file already exists.
# Skipping GCA_022305115.1 — file already exists.
# Skipping GCF_000164965.1 — file already exists.
# Skipping GCF_000183685.1 — file already exists.
# Skipping GCF_000209855.1 — file already exists.
# Skipping GCF_000178275.1 — file already exists.
# Skipping GCF_964259715.1 — file already exists.
# Skipping GCF_025145845.1 — file already exists.
# Skipping GCF_000169015.1 — file already exists.
# Skipping GCF_000165905.1 — file already exists.
# Skipping GCF_025147765.1 — file already exists.
# Skipping GCF_000265095.1 — file already exists.
# Skipping GCF_040095415.1 — file already exists.
# Skipping GCF_000006865.1 — file already exists.
# Skipping GCF_000273525.1 — file already exists.
# Skipping GCF_000146185.1 — file already exists.
# Skipping GCF_000153925.1 — file already exists.
# Skipping GCF_964250545.1 — file already exists.
# Skipping GCF_964260535.1 — file already exists.
# Skipping GCF_900445515.1 — file already exists.
# Skipping GCF_017504145.1 — file already exists.
# Skipping GCF_000003135.1 — file already exists.
# Skipping GCF_000154365.1 — file already exists.
# Skipping GCF_000210075.1 — file already exists.
# Skipping GCF_000154125.1 — file already exists.
# Skipping GCF_964238615.1 — file already exists.
# Skipping GCF_900624785.1 — file already exists.
# Skipping GCF_000196575.1 — file already exists.
# Skipping GCF_964239605.1 — file already exists.
# Skipping GCF_046199715.1 — file already exists.
# Skipping GCF_028743435.1 — file already exists.
# Skipping GCF_964259635.1 — file already exists.
# Skipping GCF_900537995.1 — file already exists.
# Skipping GCF_000210735.1 — file already exists.
# Skipping GCF_000210615.1 — file already exists.
# Skipping GCF_000210035.1 — file already exists.
# Skipping GCF_000011825.1 — file already exists.
# Skipping GCF_000225845.1 — file already exists.
# Skipping GCF_964260485.1 — file already exists.

# %% [markdown]
# ## Retrieve info for KOs--including functionalities

# %%
gene_df = pd.read_csv("gene_df_info.csv")

# %%
unique_kos = gene_df['kegg_orthology'].dropna().unique()

# %%
#retrieve KO descriptions
kegg_descriptions = {}
for ko in tqdm(unique_kos, desc="Fetching KO definitions"):
    if not ko.startswith("K"):
        continue 
    try:
        response = requests.get(f"https://rest.kegg.jp/get/ko:{ko}", timeout=10)
        # print(ko)
        if response.status_code == 200:
            lines = response.text.split("\n")
            # print(lines)
            for line in lines:
                if line.startswith("NAME"):
                    kegg_descriptions[ko] = line.replace("NAME", "").strip()
                    # print(kegg_descriptions[ko])
                    break
        else:
            kegg_descriptions[ko] = None
    except Exception as e:
        print(f"Failed to fetch KO {ko}: {e}")
        kegg_descriptions[ko] = None

#Mapping....
gene_df['ko_description'] = gene_df['kegg_orthology'].map(kegg_descriptions)
# Out:
# Fetching KO definitions: 100%|████████████████| 483/483 [11:46<00:00,  1.46s/it]

# %%
gene_df.to_csv('gene_df_info.csv', index=False)

# %%
gene_df.head()
# Out:
#                           model          gene_id kegg_orthology  ecnumber  \
# 0  Streptococcus_pneumoniae_G54  g.1878.peg.1024            NaN       NaN
# 1  Streptococcus_pneumoniae_G54  g.1878.peg.1024         K00605  2.1.2.10
# 2  Streptococcus_pneumoniae_G54  g.1878.peg.1024         K00281  2.1.2.10
# 3  Streptococcus_pneumoniae_G54  g.1878.peg.1024         K00282  2.1.2.10
# 4  Streptococcus_pneumoniae_G54  g.1878.peg.1024         K00283  2.1.2.10
#
#                                            subsystem  \
# 0                                  Folate metabolism
# 1  Glycine, serine, alanine and threonine metabolism
# 2                                  Folate metabolism
# 3                                  Folate metabolism
# 4                                  Folate metabolism
#
#                 description  isHuman    seedID genome_accession  ncbiid  \
# 0    Aminomethyltransferase    False  rxn01652  GCF_000019825.1  512566
# 1  Glycine cleavage complex    False  rxn06600  GCF_000019825.1  512566
# 2   Glycine Cleavage System    False  rxn00908  GCF_000019825.1  512566
# 3   Glycine Cleavage System    False  rxn00908  GCF_000019825.1  512566
# 4   Glycine Cleavage System    False  rxn00908  GCF_000019825.1  512566
#
#                                       ko_description matched_gene locus_tag  \
# 0                                                NaN         None      None
# 1  glycine cleavage system T protein (aminomethyl...         None      None
# 2  glycine cleavage system P protein (glycine deh...         None      None
# 3  glycine cleavage system P protein (glycine deh...         None      None
# 4  glycine cleavage system P protein (glycine deh...         None      None
#
#   protein_id matched_product
# 0       None            None
# 1       None            None
# 2       None            None
# 3       None            None
# 4       None            None

# %% [markdown]
# ## Search genes by KO description in GenBank files

# %%
gene_df = pd.read_csv("gene_df_info.csv")

# %%
gene_df[['matched_gene', 'locus_tag', 'protein_id', 'matched_product']] = None

gbff_dir = Path("GenBank_files")

# %%
for idx, row in tqdm(gene_df.iterrows(), total=gene_df.shape[0], desc="Matching KO to GenBank"):
    accession = row['genome_accession']
    target_function = str(row['ko_description']).strip().lower()
    if not target_function or pd.isna(accession):
        continue  

    gbff_path = gbff_dir / f"{accession}.gbff"
    if not gbff_path.exists():
        print(f"Missing GenBank file: {gbff_path}")
        continue

    #::>> parsing GenBank file 
    found = False
    for record in SeqIO.parse(str(gbff_path), "genbank"):
        for feature in record.features:
            if feature.type == "CDS":
                product = feature.qualifiers.get("product", [""])[0].lower()
                if target_function in product:
                    gene = feature.qualifiers.get("gene", ["-"])[0]
                    locus = feature.qualifiers.get("locus_tag", ["-"])[0]
                    protein_id = feature.qualifiers.get("protein_id", ["-"])[0]

                    # Updating
                    gene_df.at[idx, 'matched_gene'] = gene
                    gene_df.at[idx, 'locus_tag'] = locus
                    gene_df.at[idx, 'protein_id'] = protein_id
                    gene_df.at[idx, 'matched_product'] = product
                    found = True
                    break
        if found:
            break
# Out:
# Matching KO to GenBank:   0%|                | 63/12832 [00:17<59:08,  3.60it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /new/benpyenv/lib/python3.10/site-packages/Bio/File.py:72, in as_handle(handleish, mode, **kwargs)
#      71 try:
# ---> 72     with open(handleish, mode, **kwargs) as fp:
#      73         yield fp
#
# TypeError: expected str, bytes or os.PathLike object, not TextIOWrapper
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[283], line 14
#      12 #::>> parsing GenBank file
#      13 found = False
# ---> 14 for record in SeqIO.parse(str(gbff_path), "genbank"):
#      15     for feature in record.features:
#      16         if feature.type == "CDS":
#
# File /new/benpyenv/lib/python3.10/site-packages/Bio/SeqIO/InsdcIO.py:109, in GenBankIterator.__next__(self)
#     107 def __next__(self):
#     108     """Return the next SeqRecord."""
# --> 109     return next(self.records)
#
# File /new/benpyenv/lib/python3.10/site-packages/Bio/GenBank/Scanner.py:512, in InsdcScanner.parse_records(self, handle, do_features)
#     510 with as_handle(handle) as handle:
#     511     while True:
# --> 512         record = self.parse(handle, do_features)
#     513         if record is None:
#     514             break
#
# File /new/benpyenv/lib/python3.10/site-packages/Bio/GenBank/Scanner.py:495, in InsdcScanner.parse(self, handle, do_features)
#     489 from Bio.GenBank.utils import FeatureValueCleaner
#     491 consumer = _FeatureConsumer(
#     492     use_fuzziness=1, feature_cleaner=FeatureValueCleaner()
#     493 )
# --> 495 if self.feed(handle, consumer, do_features):
#     496     return consumer.data
#     497 else:
#
# File /new/benpyenv/lib/python3.10/site-packages/Bio/GenBank/Scanner.py:466, in InsdcScanner.feed(self, handle, consumer, do_features)
#     464 # Features (common to both EMBL and GenBank):
#     465 if do_features:
# --> 466     self._feed_feature_table(consumer, self.parse_features(skip=False))
#     467 else:
#     468     self.parse_features(skip=True)  # ignore the data
#
# File /new/benpyenv/lib/python3.10/site-packages/Bio/GenBank/Scanner.py:422, in InsdcScanner._feed_feature_table(consumer, feature_tuples)
#     420     consumer.feature_qualifier(q_key, q_value)
#     421 else:
# --> 422     consumer.feature_qualifier(q_key, q_value.replace("\n", " "))
#
# File /new/benpyenv/lib/python3.10/site-packages/Bio/GenBank/__init__.py:751, in _FeatureConsumer.feature_qualifier(self, key, value)
#     747     value = value[1:-1]
#     749 # Handle NCBI escaping
#     750 # Warn if escaping is not according to standard
# --> 751 if re.search(r'[^"]"[^"]|^"[^"]|[^"]"$', value):
#     752     warnings.warn(
#     753         'The NCBI states double-quote characters like " should be escaped as "" '
#     754         "(two double - quotes), but here it was not: %r" % value,
#     755         BiopythonParserWarning,
#     756     )
#     757 # Undo escaping, repeated double quotes -> one double quote
#
# File /usr/lib/python3.10/re.py:200, in search(pattern, string, flags)
#     197 def search(pattern, string, flags=0):
#     198     """Scan through string looking for a match to the pattern, returning
#     199     a Match object, or None if no match was found."""
# --> 200     return _compile(pattern, flags).search(string)
#
# File /usr/lib/python3.10/re.py:293, in _compile(pattern, flags)
#     291     flags = flags.value
#     292 try:
# --> 293     return _cache[type(pattern), pattern, flags]
#     294 except KeyError:
#     295     pass
#
# KeyboardInterrupt:

# %%
for org in list(ess_genes.keys()):
organism = "Streptococcus pneumoniae G54"
ko_function = "folylpoly glutamate synthase"  # from K01714

# Search protein database
query = f"{ko_function}[Protein name] AND {organism}[Organism]"

handle = Entrez.esearch(db="protein", term=query, retmax=10)
record = Entrez.read(handle)
handle.close()

ids = record['IdList']
print(f"Found {len(ids)} matching proteins for {ko_function} in {organism}.")

# Fetch details
if ids:
    handle = Entrez.efetch(db="protein", id=ids, rettype="gb", retmode="text")
    print(handle.read())
    handle.close()
# Out:
# Found 0 matching proteins for folylpoly glutamate synthase in Streptococcus pneumoniae G54.

# %%
gene_info = {}

def fetch_gene(model_name, gene_id):
    model_id = f"i{model_name}"  # VMH model IDs usually start with 'i'
    url = f"https://www.vmh.life/_api/models/{model_id}/genes/{gene_id}"
    try:
        response = requests.get(url)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Gene {gene_id} in model {model_id} not found (status {response.status_code})")
            return None
    except Exception as e:
        print(f"Error fetching gene {gene_id} from {model_id}: {e}")
        return None

# Loop through all microbes and genes
for model, gene_list in data.items():
    for entry in gene_list:
        gene_id = entry["gene"]
        if gene_id not in gene_info:
            gene_data = fetch_gene(model, gene_id)
            if gene_data:
                gene_info[gene_id] = gene_data
            time.sleep(0.3)

# Save results
with open("vmh_gene_details_by_model.json", "w") as f:
    json.dump(gene_info, f, indent=2)

print("✅ Saved gene details to vmh_gene_details_by_model.json")
# Out:
# Gene g.1878.peg.1024 in model iStreptococcus_pneumoniae_G54 not found (status 404)
# Gene g.1878.peg.1219 in model iStreptococcus_pneumoniae_G54 not found (status 404)
# Gene 512566.5.peg.1185 in model iStreptococcus_pneumoniae_G54 not found (status 404)
# Gene 512566.5.peg.1792 in model iStreptococcus_pneumoniae_G54 not found (status 404)
# Gene 512566.5.peg.1565 in model iStreptococcus_pneumoniae_G54 not found (status 404)
# Gene 512566.5.peg.1083 in model iStreptococcus_pneumoniae_G54 not found (status 404)
# Gene g.1878.peg.1944 in model iStreptococcus_pneumoniae_G54 not found (status 404)
# Gene 512566.5.peg.699 in model iStreptococcus_pneumoniae_G54 not found (status 404)
# Gene 512566.5.peg.1493 in model iStreptococcus_pneumoniae_G54 not found (status 404)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[84], line 30
#      28 gene_id = entry["gene"]
#      29 if gene_id not in gene_info:
# ---> 30     gene_data = fetch_gene(model, gene_id)
#      31     if gene_data:
#      32         gene_info[gene_id] = gene_data
#
# Cell In[84], line 15, in fetch_gene(model_name, gene_id)
#      13 url = f"https://www.vmh.life/_api/models/{model_id}/genes/{gene_id}"
#      14 try:
# ---> 15     response = requests.get(url)
#      16     if response.status_code == 200:
#      17         return response.json()
#
# File /new/benpyenv/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /new/benpyenv/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /new/benpyenv/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /new/benpyenv/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /new/benpyenv/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /new/benpyenv/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File /new/benpyenv/lib/python3.10/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /new/benpyenv/lib/python3.10/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File /new/benpyenv/lib/python3.10/site-packages/urllib3/connection.py:704, in HTTPSConnection.connect(self)
#     702 try:
#     703     sock: socket.socket | ssl.SSLSocket
# --> 704     self.sock = sock = self._new_conn()
#     705     server_hostname: str = self.host
#     706     tls_in_tls = False
#
# File /new/benpyenv/lib/python3.10/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File /new/benpyenv/lib/python3.10/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %%
model = read_sbml_model('agora_models/Bacteroides_fragilis_638R.xml')

# %%
model.reactions.get_by_id('23PDE9').gpr
# Out:
# cobra.core.gene.GPR('862962.26.peg.3562 or 862962.26.peg.2915 or 862962.26.peg.1862')

# %%
# Entrez.email = "your_email@example.com"  # Replace with your email

accession = "GCF_000019825.1"
search_function = "diaminopimelate epimerase"  # From KO K01714
output_file = f"{accession}.gbff"

# Step 1: Download GenBank file from NCBI
def download_genbank(accession, filename):
    if os.path.exists(filename):
        print(f"GenBank file already exists: {filename}")
        return

    print(f"🔽 Downloading GenBank for {accession}...")
    handle = Entrez.efetch(db="nuccore", id=accession, rettype="gbwithparts", retmode="text")
    with open(filename, "w") as f:
        f.write(handle.read())
    handle.close()
    print("✅ Download complete.")

# Step 2: Search for gene with desired function
def search_gene_by_function(genbank_file, target_function):
    print(f"🔍 Searching for genes with function: '{target_function}'")
    found = False
    for record in SeqIO.parse(genbank_file, "genbank"):
        for feature in record.features:
            if feature.type == "CDS":
                product = feature.qualifiers.get("product", [""])[0].lower()
                if target_function.lower() in product:
                    gene = feature.qualifiers.get("gene", ["-"])[0]
                    locus = feature.qualifiers.get("locus_tag", ["-"])[0]
                    protein_id = feature.qualifiers.get("protein_id", ["-"])[0]
                    print(f"\n✅ Match Found:")
                    print(f"  Gene       : {gene}")
                    print(f"  Locus Tag  : {locus}")
                    print(f"  Product    : {product}")
                    print(f"  Protein ID : {protein_id}")
                    found = True
    if not found:
        print("❌ No matching gene found.")

# Run it
download_genbank(accession, output_file)
# Out:
# 🔽 Downloading GenBank file: https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/019/825/GCF_000019825.1_ASM1982v1/GCF_000019825.1_ASM1982v1_genomic.gbff.gz
# ✅ Downloaded.
# 🗜️  Decompressing GCF_000019825.1_ASM1982v1_genomic.gbff.gz
# ✅ Decompressed.
# 🔍 Searching for: diaminopimelate epimerase

# %%
# Out:
# 🔍 Searching for: folylpolyglutamate synthase
#
# ✅ Match Found:
#   Gene       : -
#   Locus Tag  : SPG_RS00950
#   Product    : folylpolyglutamate synthase/dihydrofolate synthase family protein
#   Protein ID : WP_000464336.1
#
# ✅ Match Found:
#   Gene       : -
#   Locus Tag  : SPG_RS01405
#   Product    : folylpolyglutamate synthase/dihydrofolate synthase family protein
#   Protein ID : WP_000658414.1

# %%
for record in SeqIO.parse(local_gbff, "genbank"):
    for feature in record.features:
        if feature.type == "CDS":
            product = feature.qualifiers.get("product", [""])[0]
            print(product)
# Out:
# chromosomal replication initiator protein DnaA
# DNA polymerase III subunit beta
# DUF951 family protein
# redox-regulated ATPase YchF
# aminoacyl-tRNA hydrolase
# transcription-repair coupling factor
# RNA-binding S4 domain-containing protein
# septum formation initiator family protein
# SP_0009 family protein
# serine hydrolase
# tRNA lysidine(34) synthetase TilS
# hypoxanthine phosphoribosyltransferase
# ATP-dependent zinc metalloprotease FtsH
# sigma-70 family RNA polymerase sigma factor
# transposase
# sigma(X)-activator ComW
# adenylosuccinate synthase
# tRNA adenosine(34) deaminase TadA
# dUTP diphosphatase
# histidine phosphatase family protein
# DNA repair protein RadA
# carbonic anhydrase
# PrsW family glutamic-type intramembrane protease
# ribose-phosphate diphosphokinase
# ISL3 family transposase
# Rpn family recombination-promoting nuclease/putative transposase
# DNA polymerase I
# CoA-binding protein
# YeiH family protein
# pyridoxal phosphate-dependent aminotransferase
# DNA repair protein RecO
# phosphate acyltransferase PlsX
# acyl carrier protein
# transposase family protein
# bacteriocin-like peptide BlpU
# PncF family bacteriocin immunity protein
# peptide cleavage/export ABC transporter ComA
# competence pheromone export protein ComB
# phosphoribosylaminoimidazolesuccinocarboxamide synthase
# phosphoribosylformylglycinamidine synthase
# amidophosphoribosyltransferase
# phosphoribosylformylglycinamidine cyclo-ligase
# phosphoribosylglycinamide formyltransferase
# VanZ family protein
# bifunctional phosphoribosylaminoimidazolecarboxamide formyltransferase/IMP cyclohydrolase
# phosphoribosylamine--glycine ligase
# hypothetical protein
# 5-(carboxyamino)imidazole ribonucleotide mutase
# 5-(carboxyamino)imidazole ribonucleotide synthase
# hypothetical protein
# adenylosuccinate lyase
# LPXTG-anchored beta-N-acetylhexosaminidase StrH
# GntR family transcriptional regulator
# beta-galactosidase
# PTS system mannose/fructose/N-acetylgalactosamine-transporter subunit IIB
# PTS mannose/fructose/sorbose/N-acetylgalactosamine transporter subunit IIC
# PTS system mannose/fructose/sorbose family transporter subunit IID
# PTS sugar transporter subunit IIA
# SIS domain-containing protein
# aldose epimerase family protein
# CAP domain-containing protein
# zinc metalloprotease ZmpC
# VOC family protein
# sugar O-acetyltransferase
# nucleoside phosphorylase
# TrkH family potassium uptake protein
# TrkA family potassium uptake protein
# hypothetical protein
# hypothetical protein
# hypothetical protein
# PavB family fibronectin-binding SSURE repeat adhesin
# response regulator transcription factor
# HAMP domain-containing sensor histidine kinase
# 30S ribosomal protein S4
# IS630 transposase-related protein
# hypothetical protein
# hypothetical protein
# hypothetical protein
# sugar ABC transporter permease
# carbohydrate ABC transporter permease
# ABC transporter substrate-binding protein
# rhodanese-related sulfurtransferase
# DUF4299 family protein
# DUF6574 domain-containing protein
# DUF4097 domain-containing protein
# DUF1700 domain-containing protein
# PadR family transcriptional regulator
# CynX/NimT family MFS transporter
# glycosyltransferase family 2 protein
# nucleoside-diphosphate sugar epimerase/dehydratase
# hypothetical protein
# HAD family hydrolase
# L-serine ammonia-lyase, iron-sulfur-dependent, subunit alpha
# L-serine ammonia-lyase, iron-sulfur-dependent subunit beta
# LysM peptidoglycan-binding domain-containing protein
# DNA-binding protein
# lactococcin 972 family bacteriocin
# bacteriocin-associated integral membrane family protein
# ABC transporter ATP-binding protein
# ABC transporter substrate-binding protein
# argininosuccinate synthase domain-containing protein
# DNA-binding protein
# hypothetical protein
# hypothetical protein
# hypothetical protein
# hypothetical protein
# hypothetical protein
# hypothetical protein
# hypothetical protein
# SPH_0224 family bacteriocin-like peptide
# hypothetical protein
# hypothetical protein
# hypothetical protein
# hypothetical protein
# hypothetical protein
# hypothetical protein
# hypothetical protein
# pneumococcal surface protein A
# tRNA 2-thiouridine(34) synthase MnmA
# NUDIX hydrolase
# tRNA uridine-5-carboxymethylaminomethyl(34) synthesis enzyme MnmG
# ribonuclease J
# DNA-dependent RNA polymerase subunit epsilon
# hypothetical protein
# fratricide two-peptide bacteriocin subunit CibB
# fratricide two-peptide bacteriocin subunit CibA
# tRNA (adenosine(37)-N6)-threonylcarbamoyltransferase complex dimerization subunit type 1 TsaB
# ribosomal protein S18-alanine N-acetyltransferase
# tRNA (adenosine(37)-N6)-threonylcarbamoyltransferase complex transferase subunit TsaD
# ISL3 family transposase
# transposase
# glycosyltransferase family 4 protein
# glycosyltransferase family 4 protein
# glycosyltransferase family 2 protein
# ABC transporter ATP-binding protein
# IS1380 family transposase
# PIG-L family deacetylase
# nucleotide sugar dehydrogenase
# XRE/MutR family transcriptional regulator
# hypothetical protein
# type II CAAX endopeptidase family protein
# CPBP family intramembrane glutamic endopeptidase
# MFS transporter
# AzlC family ABC transporter permease
# AzlD domain-containing protein
# amino acid ABC transporter substrate-binding protein
# MetQ/NlpA family ABC transporter substrate-binding protein
# M20/M25/M40 family metallo-hydrolase
# methionine ABC transporter ATP-binding protein
# methionine ABC transporter permease
# MptD family putative ECF transporter S component
# YesL family protein
# sensor histidine kinase
# response regulator transcription factor
# hypothetical protein
# class Ib ribonucleoside-diphosphate reductase assembly flavoprotein NrdI
# NRAMP family divalent metal transporter
# DUF3021 domain-containing protein
# LytTR family DNA-binding domain-containing protein
# DNA mismatch repair endonuclease MutL
# 6,7-dimethyl-8-ribityllumazine synthase
# bifunctional 3,4-dihydroxy-2-butanone-4-phosphate synthase/GTP cyclohydrolase II
# riboflavin synthase
# bifunctional diaminohydroxyphosphoribosylaminopyrimidine deaminase/5-amino-6-(5-phosphoribosylamino)uracil reductase RibD
# Holliday junction branch migration protein RuvA
# DNA-3-methyladenine glycosylase I
# type II CAAX endopeptidase family protein
# S66 peptidase family protein
# DUF1129 domain-containing protein
# magnesium transporter CorA family protein
# excinuclease ABC subunit UvrA
# Xaa-Pro peptidase family protein
# transcriptional regulator Spx
# SP0191 family lipoprotein
# IreB family regulatory phosphoprotein
# Holliday junction resolvase RuvX
# DUF1292 domain-containing protein
# folylpolyglutamate synthase/dihydrofolate synthase family protein
# SP_0198 family lipoprotein
# cardiolipin synthase
# hypothetical protein
# hypothetical protein
# anaerobic ribonucleoside-triphosphate reductase
# hypothetical protein
# GNAT family N-acetyltransferase
# anaerobic ribonucleoside-triphosphate reductase activating protein
# phosphoribulokinase
# 30S ribosomal protein S10
# 50S ribosomal protein L3
# 50S ribosomal protein L4
# 50S ribosomal protein L23
# 50S ribosomal protein L2
# 30S ribosomal protein S19
# 50S ribosomal protein L22
# 30S ribosomal protein S3
# 50S ribosomal protein L16
# 50S ribosomal protein L29
# 30S ribosomal protein S17
# 50S ribosomal protein L14
# 50S ribosomal protein L24
# 50S ribosomal protein L5
# 30S ribosomal protein S14
# 30S ribosomal protein S8
# 50S ribosomal protein L6
# 50S ribosomal protein L18
# 30S ribosomal protein S5
# 50S ribosomal protein L30
# 50S ribosomal protein L15
# preprotein translocase subunit SecY
# adenylate kinase
# translation initiation factor IF-1
# 50S ribosomal protein L36
# 30S ribosomal protein S13
# 30S ribosomal protein S11
# DNA-directed RNA polymerase subunit alpha
# 50S ribosomal protein L17
# ACT domain-containing protein
# PFL family protein
# histidine phosphatase family protein
# iron ABC transporter permease
# ABC transporter ATP-binding protein
# extracellular solute-binding protein
# helix-turn-helix domain-containing protein
# glycyl-radical enzyme activating protein
# DeoR/GlpR family DNA-binding transcription regulator
# sugar-binding transcriptional regulator
# PTS lactose/cellobiose transporter subunit IIA
# PTS sugar transporter subunit IIB
# PTS sugar transporter subunit IIC
# glycyl radical protein
# fructose-6-phosphate aldolase
# glycerol dehydrogenase
# leucine--tRNA ligase
# GNAT family protein
# GNAT family N-acetyltransferase
# type I toxin-antitoxin system Fst family toxin
# Holliday junction branch migration DNA helicase RuvB
# nucleotidyltransferase family protein
# isoprenyl transferase
# phosphatidate cytidylyltransferase
# RIP metalloprotease RseP
# proline--tRNA ligase
# 6-phospho-beta-glucosidase
# glutamine--fructose-6-phosphate transaminase (isomerizing)
# LLM class flavin-dependent oxidoreductase
# LPXTG-anchored pullulanase SpuA
# 30S ribosomal protein S12
# 30S ribosomal protein S7
# elongation factor G
# PolC-type DNA polymerase III
# type II toxin-antitoxin system RelB/DinJ family antitoxin
# type II toxin-antitoxin system YafQ family toxin
# hypothetical protein
# aminopeptidase
# GlsB/YeaQ/YmgE family stress response membrane protein
# pseudouridine synthase
# aminopeptidase C
# PTS system mannose/fructose/sorbose family transporter subunit IID
# PTS mannose/fructose/sorbose transporter subunit IIC
# PTS sugar transporter subunit IIB
# alcohol dehydrogenase AdhP
# Cof-type HAD-IIB family hydrolase
# NCS2 family permease
# CPBP family intramembrane glutamic endopeptidase
# dihydropteroate synthase
# folylpolyglutamate synthase/dihydrofolate synthase family protein
# GTP cyclohydrolase I FolE
# 2-amino-4-hydroxy-6- hydroxymethyldihydropteridine diphosphokinase
# DUF960 domain-containing protein
# 50S ribosomal protein L13
# 30S ribosomal protein S9
# tyrosine-type recombinase/integrase
# hypothetical protein
# TIM-barrel domain-containing protein
# glutathione peroxidase
# LPXTG-anchored hyaluronate lyase
# IS200/IS605 family transposase
# IS200/IS605 family transposase
# bifunctional 2-keto-4-hydroxyglutarate aldolase/2-keto-3-deoxy-6-phosphogluconate aldolase
# sugar kinase
# RpiB/LacA/LacB family sugar-phosphate isomerase
# gluconate 5-dehydrogenase
# PTS sugar transporter subunit IIA
# glycoside hydrolase family 88 protein
# PTS system mannose/fructose/N-acetylgalactosamine-transporter subunit IIB
# PTS mannose/fructose/sorbose/N-acetylgalactosamine transporter subunit IIC
# PTS system mannose/fructose/sorbose family transporter subunit IID
# preprotein translocase subunit YajC
# alginate lyase family protein
# LacI family DNA-binding transcriptional regulator
# hypothetical protein
# hypothetical protein
# DUF3278 domain-containing protein
# helix-turn-helix transcriptional regulator
# 16S rRNA (cytosine(1402)-N(4))-methyltransferase RsmH
# cell division protein FtsL
# penicillin-binding protein 2X
# phospho-N-acetylmuramoyl-pentapeptide- transferase
# ATP-dependent Clp protease ATP-binding subunit
# S-ribosylhomocysteine lyase
# DUF1846 domain-containing protein
# alpha-glucosidase
# hypothetical protein
# transposase
# capsular polysaccharide biosynthesis protein Cps4A
# capsular polysaccharide biosynthesis protein Cps4B
# capsular polysaccharide biosynthesis protein CpsC
# polysaccharide biosynthesis tyrosine autokinase CpsD
# sugar transferase
# WecB/TagA/CpsF family glycosyltransferase
# LicD family protein
# glycosyltransferase
# O-antigen polymerase
# hypothetical protein
# UDP-N-acetylglucosamine 2-epimerase (non-hydrolyzing)
# glucose-1-phosphate thymidylyltransferase RfbA
# dTDP-4-dehydrorhamnose 3,5-epimerase family protein
# dTDP-glucose 4,6-dehydratase
# dTDP-4-dehydrorhamnose reductase
# IS66 family transposase
# IS66 family transposase
# peptide ABC transporter substrate-binding protein
# SpGH101 family endo-alpha-N-acetylgalactosaminidase
# penicillin-binding protein PBP1A
# Holliday junction resolvase RecU
# DUF1273 domain-containing protein
# cell division regulator GpsB
# class I SAM-dependent RNA methyltransferase
# mid-cell-anchored protein MapZ
# NADP-dependent phosphogluconate dehydrogenase
# response regulator transcription factor
# choline-binding protein CbpC
# MFS transporter
# lanthionine synthetase LanC family protein
# transposase
# mevalonate kinase
# diphosphomevalonate decarboxylase
# phosphomevalonate kinase
# type 2 isopentenyl-diphosphate Delta-isomerase
# cell wall-active antibiotics response protein LiaF
# sensor histidine kinase
# response regulator transcription factor
# DNA alkylation repair protein
# hypothetical protein
# choline-binding protein CbpG
# choline-binding protein CbpF
# IS3 family transposase
# PTS mannitol-specific transporter subunit IIBC
# transcription antiterminator
# PTS sugar transporter subunit IIA
# mannitol-1-phosphate 5-dehydrogenase
# trigger factor
# ATP-dependent RecD-like DNA helicase
# hypothetical protein
# signal peptidase I
# ribonuclease HIII
# cell division protein ZapA
# CvpA family protein
# endonuclease MutS2
# sodium:alanine symporter family protein
# carboxymuconolactone decarboxylase family protein
# TDT family transporter
# serine--tRNA ligase
# DUF956 family protein
# aspartate kinase
# enoyl-CoA hydratase
# MarR family transcriptional regulator
# beta-ketoacyl-ACP synthase III
# acyl carrier protein
# enoyl-[acyl-carrier-protein] reductase FabK
# ACP S-malonyltransferase
# 3-oxoacyl-[acyl-carrier-protein] reductase
# beta-ketoacyl-ACP synthase II
# acetyl-CoA carboxylase biotin carboxyl carrier protein
# 3-hydroxyacyl-ACP dehydratase FabZ
# acetyl-CoA carboxylase biotin carboxylase subunit
# acetyl-CoA carboxylase, carboxyltransferase subunit beta
# acetyl-CoA carboxylase carboxyl transferase subunit alpha
# biofilm-regulating peptide BriC
# hypothetical protein
# CPBP family intramembrane glutamic endopeptidase
# transcription antitermination factor NusB
# Asp23/Gls24 family envelope stress response protein
# elongation factor P
# Asp-tRNA(Asn)/Glu-tRNA(Gln) amidotransferase subunit GatB
# Asp-tRNA(Asn)/Glu-tRNA(Gln) amidotransferase subunit GatA
# Asp-tRNA(Asn)/Glu-tRNA(Gln) amidotransferase subunit GatC
# peptide chain release factor 3
# glycosyltransferase family 8 protein
# 50S ribosomal protein L28
# Asp23/Gls24 family envelope stress response protein
# DAK2 domain-containing protein
# ISL3-like element IS1167A family transposase
# acetolactate synthase large subunit
# acetolactate synthase small subunit
# ketol-acid reductoisomerase
# hypothetical protein
# hypothetical protein
# threonine ammonia-lyase IlvA
# hypothetical protein
# amino acid ABC transporter ATP-binding protein
# ABC transporter substrate-binding protein/permease
# DUF2207 domain-containing protein
# IS110 family transposase
# hypothetical protein
# undecaprenyl-diphosphate phosphatase
# DNA polymerase IV
# formate C-acetyltransferase
# hypothetical protein
# hypothetical protein
# ROK family transcriptional regulator
# PTS sugar transporter subunit IIC
# DUF4838 domain-containing protein
# PTS lactose/cellobiose transporter subunit IIA
# 6-phospho-beta-galactosidase
# PTS transporter subunit EIIC
# TrkH family potassium uptake protein
# Trk system potassium transporter TrkA
# S-adenosyl-l-methionine hydroxide adenosyltransferase family protein
# ECF-type riboflavin transporter substrate-binding protein
# hypothetical protein
# ABC transporter ATP-binding protein
# energy-coupling factor transporter transmembrane component T
# tRNA (cytidine(34)-2'-O)-methyltransferase
# ECF transporter S component
# phosphatase PAP2 family protein
# hypothetical protein
# GNAT family N-acetyltransferase
# DNA-directed RNA polymerase subunit delta
# hypothetical protein
# CTP synthase
# Na/Pi cotransporter family protein
# bacterial Ig-like domain-containing protein
# phosphoglycerate kinase
# IS1380 family transposase
# aromatic acid exporter family protein
# transcriptional repressor GlnR
# type I glutamate--ammonia ligase
# hypothetical protein
# hypothetical protein
# restriction endonuclease subunit S
# restriction endonuclease subunit S
# class I SAM-dependent DNA methyltransferase
# DEAD/DEAH box helicase family protein
# DUF2812 domain-containing protein
# heat-inducible transcriptional repressor HrcA
# nucleotide exchange factor GrpE
# molecular chaperone DnaK
# hypothetical protein
# molecular chaperone DnaJ
# hypothetical protein
# hypothetical protein
# HIT family protein
# ABC transporter ATP-binding protein
# ABC transporter permease
# hypothetical protein
# LytTR family DNA-binding domain-containing protein
# LytTR family DNA-binding domain-containing protein
# sensor histidine kinase
# quorum-sensing system pheromone BlpC
# bacteriocin secretion accessory protein
# peptide cleavage/export ABC transporter BlpA
# bacteriocin class II family protein
# hypothetical protein
# IS5 family transposase
# two-peptide bacteriocin subunit BlpM
# two-peptide bacteriocin subunit BlpN
# bacteriocin-like peptide BlpO
# PncF family bacteriocin immunity protein
# hypothetical protein
# CPBP family intramembrane glutamic endopeptidase
# immunity protein BlpZ
# type II CAAX endopeptidase family protein
# phosphotransferase family protein
# tRNA (guanosine(46)-N7)-methyltransferase TrmB
# ribosome maturation factor RimP
# transcription termination factor NusA
# YlxR family protein
# YlxQ-related RNA-binding protein
# translation initiation factor IF-2
# 30S ribosome-binding factor RbfA
# IS1380-like element ISSpn5 family transposase
# hypothetical protein
# hypothetical protein
# hypothetical protein
# DUF1858 domain-containing protein
# DUF438 domain-containing protein
# DUF1912 family protein
# helix-hairpin-helix domain-containing protein
# hypothetical protein
# GNAT family protein
# AAA family ATPase
# valine--tRNA ligase
# DUF3883 domain-containing protein
# Fic/DOC family protein
# IS3 family transposase
# PRD domain-containing protein
# beta-glucoside-specific PTS transporter subunit IIABC
# glycoside hydrolase family 1 protein
# phenylalanine--tRNA ligase subunit alpha
# N-acetyltransferase
# phenylalanine--tRNA ligase subunit beta
# endonuclease/exonuclease/phosphatase family protein
# helix-turn-helix domain-containing protein
# helix-turn-helix transcriptional regulator
# 5-methyltetrahydropteroyltriglutamate-- homocysteine S-methyltransferase
# methylenetetrahydrofolate reductase [NAD(P)H]
# polyribonucleotide nucleotidyltransferase
# serine O-acetyltransferase
# GNAT family N-acetyltransferase
# cysteine--tRNA ligase
# Mini-ribonuclease 3
# helix-turn-helix domain-containing protein
# hypothetical protein
# group II intron maturase-specific domain-containing protein
# ABC transporter permease
# ABC transporter ATP-binding subunit Vex2
# ABC transporter permease subunit Vex3
# putative autolysis signal peptide Pep27
# response regulator transcription factor VncR
# sensor histidine kinase VncS
# class II fructose-bisphosphate aldolase
# ferric reductase-like transmembrane domain-containing protein
# amino acid ABC transporter permease
# amino acid ABC transporter permease
# transporter substrate-binding domain-containing protein
# amino acid ABC transporter ATP-binding protein
# single-stranded-DNA-specific exonuclease RecJ
# ribonuclease J
# alpha/beta hydrolase family protein
# peptidoglycan bridge formation alanyltransferase MurM
# peptidoglycan bridge formation alanyltransferase MurN
# M57 family metalloprotease
# excinuclease ABC subunit UvrC
# metallophosphoesterase family protein
# amino acid ABC transporter substrate-binding protein
# nitroreductase family protein
# dipeptidase PepV
# uracil-DNA glycosylase family protein
# rhodanese-like domain-containing protein
# branched-chain amino acid transport system II carrier protein
# M42 family metallopeptidase
# HIT family protein
# LD-carboxypeptidase LdcB/DacB
# hypothetical protein
# 50S ribosomal protein L11
# 50S ribosomal protein L1
# ISL3 family transposase
# group II intron reverse transcriptase/maturase
# hypothetical protein
# protein-export chaperone SecB
# ATP-binding cassette domain-containing protein
# ABC-2 family transporter protein
# ABC transporter permease
# hypothetical protein
# hypothetical protein
# hypothetical protein
# S8 family serine peptidase
# PTS sugar transporter subunit IIA
# PTS sugar transporter subunit IIB
# PTS galactitol transporter subunit IIC
# hypothetical protein
# LPXTG-anchored adhesin/beta-galactosidase BgaA
# transposase
# transposase
# transposase
# DUF3397 domain-containing protein
# TIGR01212 family radical SAM protein
# class I SAM-dependent methyltransferase
# hypothetical protein
# sodium:proton antiporter
# YihY/virulence factor BrkB family protein
# thiol-disulfide oxidoreductase-associated membrane protein CcdA2
# redoxin family protein
# peptide-methionine (R)-S-oxide reductase MsrB
# response regulator transcription factor
# sensor histidine kinase
# TIGR01440 family protein
# ZmpA/ZmpB/ZmpC family metallo-endopeptidase
# aminodeoxychorismate synthase component I
# alpha/beta hydrolase
# N-acetylmuramoyl-L-alanine amidase family protein
# ROK family glucokinase
# thymidylate synthase
# DUF3042 family protein
# tRNA (adenosine(37)-N6)-dimethylallyltransferase MiaA
# GTPase HflX
# cystathionine beta-lyase
# ribonuclease Z
# SDR family oxidoreductase
# LysR family transcriptional regulator
# YqgQ family protein
# rhodanese-like domain-containing protein
# hypothetical protein
# pseudouridine synthase
# translational GTPase TypA
# DUF3165 family protein
# lactococcin 972 family bacteriocin
# bacteriocin-associated integral membrane family protein
# ABC transporter ATP-binding protein
# UDP-N-acetylmuramoyl-L-alanine--D-glutamate ligase
# UDP-N-acetylglucosamine--N-acetylmuramyl- (pentapeptide) pyrophosphoryl-undecaprenol N-acetylglucosamine transferase
# cell division protein DivIB
# orotidine-5'-phosphate decarboxylase
# orotate phosphoribosyltransferase
# hypothetical protein
# hypothetical protein
# hypothetical protein
# hypothetical protein
# ABC transporter ATP-binding protein
# cysteine ABC transporter substrate-binding protein
# amino acid ABC transporter ATP-binding protein
# amino acid ABC transporter permease
# amino acid ABC transporter permease
# lactate oxidase
# lysine--tRNA ligase
# L-lactate oxidase
# TenA family protein
# hypothetical protein
# hydroxyethylthiazole kinase
# thiamine phosphate synthase
# ECF transporter S component
# ABC transporter ATP-binding protein
# energy-coupling factor transporter transmembrane component T
# thiaminase II
# energy coupling factor transporter S component ThiW
# hydroxyethylthiazole kinase
# thiamine phosphate synthase
# bifunctional hydroxymethylpyrimidine kinase/phosphomethylpyrimidine kinase
# CopY/TcrY family copper transport repressor
# cupredoxin domain-containing protein
# heavy metal translocating P-type ATPase
# pyruvate oxidase
# VOC family protein
# IS630 family transposase
# family 1 glycosylhydrolase
# mannose-6-phosphate isomerase, class I
# sodium-dependent transporter
# MerR family transcriptional regulator
# 8-oxo-dGTP diphosphatase
# NAD(P)/FAD-dependent oxidoreductase
# DegV family protein
# TetR/AcrR family transcriptional regulator
# cytidine/deoxycytidylate deaminase family protein
# uracil phosphoribosyltransferase
# ATP-dependent Clp protease proteolytic subunit ClpP
# YlbG family protein
# ABC transporter substrate-binding protein
# branched-chain amino acid ABC transporter permease
# branched-chain amino acid ABC transporter permease
# ABC transporter ATP-binding protein
# ABC transporter ATP-binding protein
# CBS domain-containing protein
# peptide chain release factor 2
# cell division ATP-binding protein FtsE
# permease-like cell division protein FtsX
# PTS transporter subunit IIBC
# endonuclease/exonuclease/phosphatase family protein
# DEAD/DEAH box helicase
# methionine adenosyltransferase
# dihydroorotate oxidase
# DNA polymerase III subunit delta
# superoxide dismutase SodA
# YutD family protein
# 23S rRNA (adenine(2503)-C(2))-methyltransferase RlmN
# VanZ family protein
# ABC-F family ATP-binding cassette domain-containing protein
# peptidylprolyl isomerase
# hypothetical protein
# hypothetical protein
# 30S ribosomal protein S16
# RNA-binding protein KphA
# MazG nucleotide pyrophosphohydrolase domain-containing protein
# alpha/beta hydrolase
# ribosome maturation factor RimM
# tRNA (guanosine(37)-N1)-methyltransferase TrmD
# ATP cone domain-containing protein
# hypothetical protein
# YdbC family protein
# hypothetical protein
# biotin transporter BioY
# glutathione-disulfide reductase
# efflux RND transporter periplasmic adaptor subunit
# ABC transporter ATP-binding protein
# ABC transporter permease
# methionine--tRNA ligase
# hypothetical protein
# PadR family transcriptional regulator
# membrane protein
# aldo/keto reductase family oxidoreductase
# DUF2829 domain-containing protein
# 3-oxoacyl-ACP reductase
# NUDIX hydrolase
# putative PEP-binding protein
# ASCH domain-containing protein
# M1 family metallopeptidase
# two-component system response regulator CiaR
# two-component system sensor histidine kinase CiaH
# DUF3270 domain-containing protein
# peptidase U32 family protein
# bifunctional DnaQ family exonuclease/ATP-dependent helicase
# FtsW/RodA/SpoVE family cell cycle protein
# DJ-1 family glyoxalase III
# HAD family hydrolase
# DNA topoisomerase (ATP-hydrolyzing) subunit B
# septation ring formation regulator EzrA
# IS66 family insertion sequence element accessory protein TnpB
# DUF1827 family protein
# NUDIX hydrolase
# IS630 transposase-related protein
# ATP-dependent Clp protease ATP-binding subunit
# YkuJ family protein
# amino acid ABC transporter permease
# amino acid ABC transporter ATP-binding protein
# bifunctional methylenetetrahydrofolate dehydrogenase/methenyltetrahydrofolate cyclohydrolase
# NAD(P)H-hydrate dehydratase
# ribose-5-phosphate isomerase RpiA
# phosphopentomutase
# DUF1697 domain-containing protein
# purine-nucleoside phosphorylase
# lipase family protein
# discoidin domain-containing protein
# thiol-activated cytolysin C-terminal domain-containing protein
# purine-nucleoside phosphorylase
# DNA topology modulation protein
# 30S ribosomal protein S20
# type I pantothenate kinase
# hypothetical protein
# class I SAM-dependent methyltransferase
# pyrimidine-nucleoside phosphorylase
# deoxyribose-phosphate aldolase
# cytidine deaminase
# BMP family protein
# ABC transporter ATP-binding protein
# ABC transporter permease
# ABC transporter permease
# IS3 family transposase
# glycerol-3-phosphate 1-O-acyltransferase PlsY
# DNA topoisomerase IV subunit B
# N-6 DNA methylase
# DNA topoisomerase IV subunit A
# branched-chain amino acid aminotransferase
# peptide ABC transporter substrate-binding protein
# DUF969 domain-containing protein
# DUF979 family protein
# pyroglutamyl-peptidase I
# DUF2969 domain-containing protein
# 30S ribosomal protein S1
# ISL3 family transposase
# GAF domain-containing protein
# DNA polymerase III subunit gamma/tau
# DUF3272 domain-containing protein
# Fe-S cluster assembly ATPase SufC
# Fe-S cluster assembly protein SufD
# cysteine desulfurase
# Fe-S cluster assembly sulfur transfer protein SufU
# Fe-S cluster assembly protein SufB
# D-alanyl-D-alanine carboxypeptidase PBP3
# cell elongation protein CozE
# DeoR/GlpR family DNA-binding transcription regulator
# 1-phosphofructokinase
# fructose-specific PTS transporter subunit EIIC
# DNA translocase FtsK
# DUF6556 family protein
# cysteine desulfurase family protein
# tRNA uracil 4-sulfurtransferase ThiI
# alpha/beta hydrolase
# esterase family protein
# ATP-grasp domain-containing protein
# hypothetical protein
# class I SAM-dependent DNA methyltransferase
# restriction endonuclease subunit S
# AbrB family transcriptional regulator
# type II toxin-antitoxin system death-on-curing family toxin
# site-specific tyrosine recombinase/integron integrase
# restriction endonuclease subunit S
# DEAD/DEAH box helicase family protein
# hypothetical protein
# arginine repressor
# Xaa-Pro dipeptidyl-peptidase
# DNA polymerase III subunit alpha
# 6-phosphofructokinase
# pyruvate kinase
# tyrosine-type recombinase/integrase
# S26 family signal peptidase
# transcriptional regulator
# DUF4300 family protein
# transposase family protein
# hypothetical protein
# alpha/beta hydrolase
# TIGR03943 family protein
# permease
# SPJ_0845 family protein
# Tex family protein
# SprT family protein
# PspC domain-containing protein
# hypothetical protein
# ABC transporter ATP-binding protein
# ABC transporter permease
# VIT family protein
# IS30 family transposase
# aminotransferase class I/II-fold pyridoxal phosphate-dependent enzyme
# IS110 family transposase
# hypothetical protein
# polyamine aminopropyltransferase
# saccharopine dehydrogenase family protein
# carboxynorspermidine decarboxylase
# agmatine deiminase
# N-carbamoylputrescine amidase
# HAD family hydrolase
# SP_0924 family bacteriocin-like peptide
# CPBP family intramembrane glutamic endopeptidase
# AraC family transcriptional regulator
# LysR family transcriptional regulator
# signal peptidase II
# RluA family pseudouridine synthase
# phosphorylcholine esterase CbpE
# glutamate 5-kinase
# glutamate-5-semialdehyde dehydrogenase
# pyrroline-5-carboxylate reductase
# dTMP kinase
# DNA polymerase III subunit delta'
# DNA replication initiation control protein YabA
# 16S rRNA (cytidine(1402)-2'-O)-methyltransferase
# CD1845 family protein
# ClbS/DfsB family four-helix bundle protein
# replication initiator protein A
# IS5 family transposase
# hypothetical protein
# methylenetetrahydrofolate--tRNA-(uracil(54)- C(5))-methyltransferase (FADH(2)-oxidizing) TrmFO
# UMP kinase
# ribosome recycling factor
# RNA-binding virulence regulatory protein CvfB
# YozE family protein
# PhoH family protein
# GNAT family N-acetyltransferase
# helix-hairpin-helix domain-containing protein
# DNA internalization-related competence protein ComEC/Rec2
# hypothetical protein
# ABC transporter ATP-binding protein
# hypothetical protein
# translation initiation factor IF-3
# 50S ribosomal protein L35
# 50S ribosomal protein L20
# VOC family protein
# dihydroorotate dehydrogenase electron transfer subunit
# dihydroorotate dehydrogenase
# endo-beta-N-acetylglucosaminidase
# Rqc2 family fibronectin-binding protein PavA
# rRNA maturation RNase YbeY
# diacylglycerol kinase
# GTPase Era
# DNA-formamidopyrimidine glycosylase
# dephospho-CoA kinase
# multidrug efflux MFS transporter
# 50S ribosomal protein L33
# preprotein translocase subunit SecG
# ribonuclease R
# SsrA-binding protein SmpB
# SAM-dependent methyltransferase TehB
# competence protein CoiA
# oligoendopeptidase F
# O-methyltransferase
# peptidylprolyl isomerase PrsA
# IS3 family transposase
# IS630 family transposase
# histidine phosphatase family protein
# aminoacyl-tRNA deacylase
# DUF368 domain-containing protein
# glycoside hydrolase family 25 protein
# bifunctional UDP-N-acetylglucosamine diphosphorylase/glucosamine-1-phosphate N-acetyltransferase GlmU
# NUDIX hydrolase
# cell wall synthase accessory phosphoprotein MacP
# 5'-methylthioadenosine/adenosylhomocysteine nucleosidase
# chromosome segregation protein RocS
# 3'-5' exonuclease
# glycerophosphodiester phosphodiesterase
# IS1380-like element ISSpn5 family transposase
# IS630 transposase-related protein
# hypothetical protein
# hypothetical protein
# thiol-disulfide oxidoreductase-associated membrane protein CcdA2
# thiol-disulfide oxidoreductase-associated lipoprotein SdbB
# amino acid permease
# zinc-binding lipoprotein AdcAII
# pneumococcal histidine triad protein PhtD
# pneumococcal histidine triad protein PhtE
# pneumococcal-type histidine triad protein
# IS110 family transposase
# HIT family hydrolase
# peptidase T
# ferrochelatase
# large conductance mechanosensitive channel protein MscL
# GtrA family protein
# QueT transporter family protein
# aspartate-semialdehyde dehydrogenase
# 4-hydroxy-tetrahydrodipicolinate synthase
# tRNA uridine-5-carboxymethylaminomethyl(34) synthesis GTPase MnmE
# 4-oxalocrotonate tautomerase
# thymidine kinase
# peptide chain release factor 1
# peptide chain release factor N(5)-glutamine methyltransferase
# L-threonylcarbamoyladenylate synthase
# GNAT family N-acetyltransferase
# serine hydroxymethyltransferase
# nucleoid-associated protein
# cell wall hydrolase Pmp23
# DUF1002 domain-containing protein
# 23S rRNA (uracil(1939)-C(5))-methyltransferase RlmD
# hypothetical protein
# helix-turn-helix transcriptional regulator
# hypothetical protein
# iron-siderophore ABC transporter substrate-binding protein
# iron ABC transporter permease
# iron ABC transporter permease
# ABC transporter ATP-binding protein
# restriction endonuclease subunit S
# DUF3847 domain-containing protein
# MobQ family relaxase
# hypothetical protein
# PcfB family protein
# phage replisome organizer N-terminal domain-containing protein
# hypothetical protein
# recombinase family protein
# hypothetical protein
# hypothetical protein
# ATP-grasp domain-containing protein
# ADP-ribosylglycohydrolase family protein
# diacylglycerol kinase family protein
# alpha amylase N-terminal ig-like domain-containing protein
# SAG1250 family conjugative relaxase
# Rgg/GadR/MutR family transcriptional regulator
# SHP2/SHP3 family peptide pheromone
# NAD(P)-binding domain-containing protein
# nucleotidyltransferase
# hypothetical protein
# hypothetical protein
# hypothetical protein
# UDP-glucose 4-epimerase GalE
# hypothetical protein
# MFS transporter
# helix-turn-helix transcriptional regulator
# transposase family protein
# FtsW/RodA/SpoVE family cell cycle protein
# phosphoenolpyruvate carboxylase
# tryptophan ABC transporter substrate-binding protein
# ABC transporter permease
# ABC transporter ATP-binding protein
# DNA primase
# RNA polymerase sigma factor RpoD
# metal-sulfur cluster assembly factor
# alpha-galactosylglucosyldiacylglycerol synthase
# glycosyltransferase family 4 protein
# PspC domain-containing protein
# DUF4044 domain-containing protein
# GTPase ObgE
# hypothetical protein
# hypothetical protein
# UDP-N-acetylglucosamine 1-carboxyvinyltransferase
# GNAT family N-acetyltransferase
# CBS-HotDog domain-containing transcription factor SpxR
# methionyl aminopeptidase
# IS5 family transposase
# DNA helicase PcrA
# DNA repair protein RadC
# gamma-glutamyl-gamma-aminobutyrate hydrolase family protein
# redox-sensing transcriptional repressor Rex
# DUF4649 family protein
# DUF1831 domain-containing protein
# cysteine desulfurase family protein
# ribose-phosphate diphosphokinase
# CYTH domain-containing protein
# GTP pyrophosphokinase family protein
# NAD kinase
# RluA family pseudouridine synthase
# phosphate acetyltransferase
# YbaB/EbfC family nucleoid-associated protein
# YoaK family protein
# 50S ribosomal protein L21
# ribosomal-processing cysteine protease Prp
# 50S ribosomal protein L27
# TIGR03943 family protein
# bifunctional riboflavin kinase/FAD synthetase
# YitT family protein
# DegV family protein
# HU family DNA-binding protein
# ABC-F family ATP-binding cassette domain-containing protein
# XRE/MutR family transcriptional regulator
# MFS transporter
# NAD-dependent DNA ligase LigA
# type I pullulanase
# NADP-dependent glyceraldehyde-3-phosphate dehydrogenase
# 1,4-alpha-glucan branching protein GlgB
# glucose-1-phosphate adenylyltransferase
# glucose-1-phosphate adenylyltransferase subunit GlgD
# glycogen synthase GlgA
# HAD-IB family phosphatase
# HAD hydrolase family protein
# glycerate kinase
# YueI family protein
# surface-displayed alpha-enolase
# tyrosine-type recombinase/integrase
# IS630 family transposase
# diacylglycerol kinase family lipid kinase
# ATP-dependent nuclease subunit B
# helicase-exonuclease AddAB subunit AddA
# hypothetical protein
# hypothetical protein
# ZmpA/ZmpB/ZmpC family metallo-endopeptidase
# zinc metalloprotease ZmpD
# IS1380-like element ISSpn5 family transposase
# ribosome biogenesis GTPase YlqF
# ribonuclease HII
# ClC family H(+)/Cl(-) exchange transporter
# tyrosine recombinase XerS
# lipoate--protein ligase
# dihydrolipoyl dehydrogenase
# dihydrolipoamide acetyltransferase
# alpha-ketoacid dehydrogenase subunit beta
# thiamine pyrophosphate-dependent dehydrogenase E1 component subunit alpha
# sodium-coupled multidrug efflux MATE transporter PdrM
# hypothetical protein
# dihydroorotase
# 8-oxo-dGTP diphosphatase
# uracil-DNA glycosylase
# hypothetical protein
# YjjG family noncanonical pyrimidine nucleotidase
# PTS mannose family transporter subunit IIA
# dihydroxyacetone kinase subunit L
# pneumococcal-type histidine triad protein
# phosphoenolpyruvate--protein phosphotransferase
# phosphocarrier protein HPr
# glutaredoxin-like protein NrdH
# class 1b ribonucleoside-diphosphate reductase subunit alpha
# class 1b ribonucleoside-diphosphate reductase subunit beta
# DeoR/GlpR family DNA-binding transcription regulator
# DUF3884 family protein
# 6-phospho-beta-galactosidase
# lactose-specific PTS transporter subunit EIIC
# PTS lactose/cellobiose transporter subunit IIA
# transcription antiterminator
# tagatose-bisphosphate aldolase
# tagatose-6-phosphate kinase
# galactose-6-phosphate isomerase subunit LacB
# galactose-6-phosphate isomerase subunit LacA
# aldose 1-epimerase family protein
# IS5 family transposase
# PTS sugar transporter subunit IIB
# PTS sugar transporter subunit IIA
# hypothetical protein
# translation elongation factor 4
# metallophosphoesterase family protein
# DNA repair protein RecN
# arginine repressor
# TlyA family RNA methyltransferase
# polyprenyl synthetase family protein
# exodeoxyribonuclease VII small subunit
# exodeoxyribonuclease VII large subunit
# uridine kinase
# bacteriocin immunity protein
# tRNA pseudouridine(55) synthase TruB
# hypothetical protein
# DUF2130 domain-containing protein
# O-acetylhomoserine aminocarboxypropyltransferase/cysteine synthase family protein
# formate/nitrite transporter family protein
# sortase SrtA
# DNA gyrase subunit A
# L-lactate dehydrogenase
# potassium channel family protein
# type II toxin-antitoxin system RelE/ParE family toxin
# DUF6290 family protein
# MBL fold metallo-hydrolase
# cell wall metabolism sensor histidine kinase VicK
# response regulator YycF
# A/G-specific adenine glycosylase
# hypothetical protein
# formate--tetrahydrofolate ligase
# phosphopantothenate--cysteine ligase
# phosphopantothenoylcysteine decarboxylase
# ECF transporter S component
# ECF transporter S component
# transcription repressor NadR
# 8-oxo-dGTP diphosphatase
# GNAT family N-acetyltransferase
# GNAT family protein
# excinuclease ABC subunit UvrB
# CPBP family intramembrane glutamic endopeptidase
# ABC transporter substrate-binding protein/permease
# amino acid ABC transporter ATP-binding protein
# glucose-6-phosphate dehydrogenase
# signal recognition particle-docking protein FtsY
# Cof-type HAD-IIB family hydrolase
# HAD family hydrolase
# chromosome segregation protein SMC
# ribonuclease III
# GMP reductase
# McrC family protein
# McrB family protein
# Sua5/YciO/YrdC/YwlC family protein
# 3-isopropylmalate dehydratase small subunit
# DUF1294 domain-containing protein
# 3-isopropylmalate dehydrogenase
# alpha-isopropylmalate synthase regulatory domain-containing protein
# MmcQ/YjbR family DNA-binding protein
# copper homeostasis protein CutC
# YbaN family protein
# type I DNA topoisomerase
# TIGR00341 family protein
# hypothetical protein
# DNA-processing protein DprA
# sugar phosphate nucleotidyltransferase
# DMT family transporter
# choline kinase LicA
# ribitol-5-phosphate dehydrogenase
# 2-C-methyl-D-erythritol 4-phosphate cytidylyltransferase
# type IV teichoic acid flippase TacF
# phosphorylcholine transferase LicD
# phosphorylcholine transferase LicD
# carbamoyl-phosphate synthase large subunit
# carbamoyl phosphate synthase small subunit
# aspartate carbamoyltransferase catalytic subunit
# bifunctional pyr operon transcriptional regulator/uracil phosphoribosyltransferase PyrR
# endonuclease III
# DUF177 domain-containing protein
# helicase BlpT
# ATP-binding cassette domain-containing protein
# zinc metalloprotease HtpX
# LemA family protein
# 16S rRNA (guanine(527)-N(7))-methyltransferase RsmG
# solute carrier family 23 protein
# signal recognition particle protein
# putative DNA-binding protein
# DUF1934 domain-containing protein
# HD domain-containing protein
# sugar-phosphatase
# 50S ribosomal protein L19
# fluoride efflux transporter CrcB
# fluoride efflux transporter CrcB
# chorismate mutase
# flavodoxin
# bifunctional oligoribonuclease/PAP phosphatase NrnA
# type B 50S ribosomal protein L31
# hypothetical protein
# transposase
# NADP-specific glutamate dehydrogenase
# hypothetical protein
# ATP-binding cassette domain-containing protein
# IS5 family transposase
# IS66 family transposase
# IS66 family transposase
# transposase
# IS66 family insertion sequence element accessory protein TnpB
# hypothetical protein
# V-type ATP synthase subunit D
# V-type ATP synthase subunit B
# V-type ATP synthase subunit A
# V-type ATP synthase subunit F
# V-type ATPase subunit
# hypothetical protein
# V-type ATP synthase subunit K
# V-type ATP synthase subunit I
# hypothetical protein
# ROK family protein
# Gfo/Idh/MocA family oxidoreductase
# exo-alpha-sialidase
# YhcH/YjgK/YiaL family protein
# sodium:solute symporter
# N-acetylneuraminate lyase
# N-acetylmannosamine-6-phosphate 2-epimerase
# MurR/RpiR family transcriptional regulator
# type II CAAX endopeptidase family protein
# transcriptional regulator
# arsenate reductase family protein
# hypothetical protein
# replication initiator protein A
# hypothetical protein
# tetracycline resistance ribosomal protection protein Tet(M)
# tetracycline resistance determinant leader peptide
# conjugal transfer protein
# bifunctional lysozyme/C40 family peptidase
# membrane protein
# ATP-binding protein
# conjugal transfer protein
# antirestriction protein ArdA
# hypothetical protein
# ISL3 family transposase
# 23S rRNA (adenine(2058)-N(6))-methyltransferase Erm(B)
# 23S rRNA methyltransferase attenuation leader peptide
# MLS leader peptide
# MobT family relaxase
# hypothetical protein
# FtsK/SpoIIIE domain-containing protein
# YdcP family protein
# YdcP family protein
# PhrA family quorum-sensing system peptide
# helix-turn-helix transcriptional regulator
# helical hairpin domain-containing protein
# SAG1250 family conjugative relaxase
# MobC family plasmid mobilization relaxosome protein
# SAG1252 family conjugative relaxosome accessory protein
# ATP-binding protein
# ATP-dependent helicase
# AAA family ATPase
# hypothetical protein
# hypothetical protein
# tyrosine-type recombinase/integrase
# zeta toxin family protein
# transposase
# hypothetical protein
# DUF3990 domain-containing protein
# hypothetical protein
# DUF5945 family protein
# DUF5965 family protein
# toprim domain-containing protein
# hypothetical protein
# Rgg/GadR/MutR family transcriptional regulator
# ABC transporter ATP-binding protein
# DUF5966 family protein
# DUF5962 family protein
# SNF2-related protein
# thrombospondin type 3 repeat-containing protein
# PBECR4 domain-containing protein
# hypothetical protein
# phage tail tip lysozyme
# hypothetical protein
# PrgI family protein
# hypothetical protein
# hypothetical protein
# type IV secretory system conjugative DNA transfer family protein
# hypothetical protein
# hypothetical protein
# putative bacteriocin export ABC transporter
# DUF1430 domain-containing protein
# lactococcin 972 family bacteriocin
# type IV toxin-antitoxin system AbiEi family antitoxin domain-containing protein
# hypothetical protein
# type II CAAX endopeptidase family protein
# hypothetical protein
# hypothetical protein
# hypothetical protein
# DNA (cytosine-5-)-methyltransferase
# replication initiator protein A
# hypothetical protein
# 50S ribosomal protein L7/L12
# 50S ribosomal protein L10
# TRZ/ATZ family protein
# ABC transporter ATP-binding protein
# ABC transporter ATP-binding protein
# peptide-methionine (R)-S-oxide reductase MsrB
# homoserine kinase
# homoserine dehydrogenase
# adaptor protein MecA
# hypothetical protein
# O-antigen polysaccharide polymerase Wzy family protein
# glycosyltransferase family 2 protein
# glycosyltransferase
# phosphorylcholine transferase LicD
# polyisoprenyl-teichoic acid--peptidoglycan teichoic acid transferase Psr
# prephenate dehydratase
# shikimate kinase
# 3-phosphoshikimate 1-carboxyvinyltransferase
# YlbF/YmcA family competence regulator
# prephenate dehydrogenase
# chorismate synthase
# 3-dehydroquinate synthase
# shikimate dehydrogenase
# type I 3-dehydroquinate dehydratase
# class I SAM-dependent rRNA methyltransferase
# hypothetical protein
# ABC transporter ATP-binding protein
# alpha-amylase
# alanine--tRNA ligase
# LURP-one-related/scramblase family protein
# hypothetical protein
# ABC transporter substrate-binding protein
# ABC transporter permease
# ABC transporter permease
# ABC transporter ATP-binding protein
# UDP-N-acetylmuramate dehydrogenase
# YhfC family glutamic-type intramembrane protease
# acetolactate decarboxylase
# PLP-dependent aminotransferase family protein
# ABC transporter substrate-binding protein
# phosphate signaling complex protein PhoU
# phosphate ABC transporter ATP-binding protein PstB
# phosphate ABC transporter ATP-binding protein PstB
# phosphate ABC transporter permease PstA
# phosphate ABC transporter permease subunit PstC
# phosphate ABC transporter substrate-binding protein PstS
# RsmF rRNA methyltransferase first C-terminal domain-containing protein
# inositol monophosphatase family protein
# UPF0223 family protein
# Spx/MgsR family RNA polymerase-binding regulatory protein
# TIGR01906 family membrane protein
# TIGR01457 family HAD-type hydrolase
# acyl-[acyl-carrier-protein] thioesterase
# radical SAM family heme chaperone HemW
# YtxH domain-containing protein
# DUF948 domain-containing protein
# prolipoprotein diacylglyceryl transferase
# HPr(Ser) kinase/phosphatase
# 30S ribosomal protein S21
# glucosamine-6-phosphate deaminase
# tRNA preQ1(34) S-adenosylmethionine ribosyltransferase-isomerase QueA
# N-acetylmuramoyl-L-alanine amidase family protein
# G5 domain-containing protein
# GNAT family N-acetyltransferase
# ammonia-dependent NAD(+) synthetase
# nicotinate phosphoribosyltransferase
# DUF6773 family protein
# helix-turn-helix transcriptional regulator
# ABC transporter permease
# ABC transporter ATP-binding protein
# U32 family peptidase
# CHY zinc finger protein
# U32 family peptidase
# ApaLI family restriction endonuclease
# site-specific DNA-methyltransferase
# glutamine-hydrolyzing GMP synthase
# GntR family transcriptional regulator
# DMT family transporter
# serine hydrolase domain-containing protein
# CppA N-terminal domain-containing protein
# SGNH/GDSL hydrolase family protein
# HAD family hydrolase
# poly-gamma-glutamate biosynthesis protein
# CapA family protein
# peptide deformylase
# 23S rRNA (guanosine(2251)-2'-O)-methyltransferase RlmB
# thioredoxin-disulfide reductase
# DUF4059 family protein
# amino acid ABC transporter ATP-binding protein
# amino acid ABC transporter permease
# arsenate reductase family protein
# methylated-DNA--[protein]-cysteine S-methyltransferase
# GNAT family N-acetyltransferase
# DUF1836 domain-containing protein
# hemolysin III family protein
# pyridoxal 5'-phosphate synthase glutaminase subunit PdxT
# pyridoxal 5'-phosphate synthase lyase subunit PdxS
# FAD-dependent oxidoreductase
# FAD:protein FMN transferase
# NADPH-dependent FMN reductase
# NAD(P)H-dependent oxidoreductase
# DUF896 family protein
# glycine--tRNA ligase subunit beta
# glycine--tRNA ligase subunit alpha
# hypothetical protein
# aldo/keto reductase
# hypothetical protein
# peptidoglycan-N-acetylglucosamine deacetylase PgdA
# PD-(D/E)XK nuclease family transposase
# Gfo/Idh/MocA family oxidoreductase
# DEAD/DEAH box helicase
# IS630 family transposase
# elongation factor Tu
# aquaglyceroporin Gla
# LPXTG cell wall anchor domain-containing protein
# MucBP domain-containing protein
# hypothetical protein
# hypothetical protein
# IS630 family transposase
# IS630 transposase-related protein
# phospho-sugar mutase
# thioredoxin
# amino acid ABC transporter substrate-binding protein
# amino acid ABC transporter ATP-binding protein
# amino acid ABC transporter permease
# hypothetical protein
# AI-2E family transporter
# lactonase family protein
# F0F1 ATP synthase subunit epsilon
# F0F1 ATP synthase subunit beta
# F0F1 ATP synthase subunit gamma
# F0F1 ATP synthase subunit alpha
# F0F1 ATP synthase subunit delta
# F0F1 ATP synthase subunit B
# F0F1 ATP synthase subunit A
# F0F1 ATP synthase subunit C
# IS30 family transposase
# GNAT family N-acetyltransferase
# transcription elongation factor GreA
# endolytic transglycosylase MltG
# GNAT family N-acetyltransferase
# GNAT family N-acetyltransferase
# UDP-N-acetylmuramate--L-alanine ligase
# hypothetical protein
# DEAD/DEAH box helicase
# PatB family C-S lyase
# cystathionine gamma-synthase
# ATP-binding cassette domain-containing protein
# ABC transporter ATP-binding protein
# hypothetical protein
# peptide ABC transporter substrate-binding protein
# polysaccharide biosynthesis protein
# UDP-N-acetylmuramoyl-L-alanyl-D-glutamate--L- lysine ligase
# CsbD family protein
# DUF1803 domain-containing protein
# YiiX/YebB-like N1pC/P60 family cysteine hydrolase
# manganese-dependent inorganic pyrophosphatase
# GIY-YIG nuclease family protein
# tRNA1(Val) (adenine(37)-N6)-methyltransferase
# S1 RNA-binding domain-containing protein
# bifunctional Cof-type HAD-IIB family hydrolase/peptidylprolyl isomerase
# 30S ribosomal protein S18
# single-stranded DNA-binding protein SsbA
# 30S ribosomal protein S6
# asparagine--tRNA ligase
# VOC family protein
# pyridoxal phosphate-dependent aminotransferase
# DUF5590 domain-containing protein
# NADPH-dependent FMN reductase
# peroxide stress protein YaaA
# YczI family protein
# hypothetical protein
# peptide deformylase
# glutathione-dependent disulfide-bond oxidoreductase
# cation-translocating P-type ATPase
# CDF family manganese efflux transporter MntE
# ABC-F family ATP-binding cassette domain-containing protein
# CCA tRNA nucleotidyltransferase
# 4-hydroxy-tetrahydrodipicolinate reductase
# DegV family protein
# DUF1149 family protein
# phosphoglucosamine mutase
# CdaR family protein
# diadenylate cyclase CdaA
# NAD(P)/FAD-dependent oxidoreductase
# DNA-binding protein WhiA
# YvcK family protein
# RNase adapter RapZ
# RidA family protein
# ribosome biogenesis GTP-binding protein YihA/YsxC
# ATP-dependent Clp protease ATP-binding subunit ClpX
# dihydrofolate reductase
# Dps family protein
# ...
# nicotinate-nucleotide adenylyltransferase
# ribosome assembly RNA-binding protein YhbY
# ribosome biogenesis GTPase YqeH
# YqeG family HAD IIIA-type phosphatase
# magnesium transporter CorA family protein
# mechanosensitive ion channel domain-containing protein
# serine/threonine transporter SstT
# aromatic acid exporter family protein
# MarR family transcriptional regulator
# DUF4649 family protein
# thioredoxin
# preQ(1) synthase
# hypothetical protein
# aquaporin
# DUF2785 domain-containing protein
# oligoendopeptidase F
# 16S rRNA (uracil(1498)-N(3))-methyltransferase
# 50S ribosomal protein L11 methyltransferase
# NUDIX hydrolase
# site-2 protease family protein
# DUF3013 family protein
# type II toxin-antitoxin system HicB family antitoxin
# type II toxin-antitoxin system HicA family toxin
# hypothetical protein
# hypothetical protein
# replication-associated recombination protein A
# glycoside hydrolase family 32 protein
# carbohydrate ABC transporter permease
# sugar ABC transporter permease
# sugar ABC transporter substrate-binding protein
# LacI family DNA-binding transcriptional regulator
# virulence factor transcriptional regulator MgaSpn
# GlsB/YeaQ/YmgE family stress response membrane protein
# alkaline shock response membrane anchor protein AmaP
# DUF2273 domain-containing protein
# Asp23/Gls24 family envelope stress response protein
# CsbD family protein
# transposase
# IS30 family transposase
# sulfite exporter TauE/SafE family protein
# SUMF1/EgtB/PvdO family nonheme iron enzyme
# PTS sugar transporter subunit IIC
# PTS lactose/cellobiose transporter subunit IIA
# PTS sugar transporter subunit IIB
# haloacid dehalogenase-like hydrolase
# PTS sugar transporter subunit IIC
# ROK family transcriptional regulator
# GNAT family N-acetyltransferase
# A24 family peptidase
# XRE family transcriptional regulator
# hypothetical protein
# prepilin peptidase
# tryptophan synthase subunit alpha
# tryptophan synthase subunit beta
# phosphoribosylanthranilate isomerase
# indole-3-glycerol phosphate synthase TrpC
# anthranilate phosphoribosyltransferase
# aminodeoxychorismate/anthranilate synthase component II
# anthranilate synthase component I
# hypothetical protein
# LacI family DNA-binding transcriptional regulator
# hypothetical protein
# MgtC/SapB family protein
# iron ABC transporter permease
# ABC transporter ATP-binding protein
# extracellular solute-binding protein
# DUF1868 domain-containing protein
# GDP-mannose 4,6-dehydratase
# hypothetical protein
# multi-ligand-binding adhesin PfbA
# DegT/DnrJ/EryC1/StrS aminotransferase family protein
# sugar transferase
# ABC transporter ATP-binding protein
# ABC transporter transmembrane domain-containing protein
# DUF421 domain-containing protein
# DUF3290 family protein
# exodeoxyribonuclease III
# VOC family protein
# hypothetical protein
# xanthine phosphoribosyltransferase
# nucleobase:cation symporter-2 family protein
# type II restriction endonuclease
# site-specific DNA-methyltransferase
# Dam family site-specific DNA-(adenine-N6)-methyltransferase
# PaaI family thioesterase
# UDP-glucose--hexose-1-phosphate uridylyltransferase
# galactokinase
# DNA-binding transcriptional regulator GalR
# alcohol dehydrogenase catalytic domain-containing protein
# stress response transcriptional regulator NmlR
# cation diffusion facilitator family transporter CzcD
# TetR/AcrR family transcriptional regulator SczA
# nicotinamide riboside transporter PnuC
# ABC transporter permease/substrate-binding protein
# ABC transporter ATP-binding protein
# nuclear transport factor 2 family protein
# MarR family transcriptional regulator
# bacteriocin immunity protein
# glutamyl aminopeptidase
# UDP-glucose 4-epimerase GalE
# hypothetical protein
# ABC transporter permease
# iron chelate uptake ABC transporter family permease subunit
# ABC transporter ATP-binding protein
# siderophore ABC transporter substrate-binding protein
# membrane protein insertion efficiency factor YidD
# pseudouridine synthase
# SMC-Scp complex subunit ScpB
# segregation/condensation protein A
# site-specific tyrosine recombinase XerD
# cyclic-di-AMP-binding protein CbpB
# metallophosphoesterase
# nucleoside-triphosphate diphosphatase
# glutamate racemase
# YneF family protein
# alpha,alpha-phosphotrehalase
# PTS system trehalose-specific EIIBC component
# trehalose operon repressor
# ISL3 family transposase
# ATP-binding cassette domain-containing protein
# oligopeptide/dipeptide ABC transporter ATP-binding protein
# oligopeptide ABC transporter permease OppC
# ABC transporter permease
# peptide ABC transporter substrate-binding protein
# IS1380-like element ISSpn5 family transposase
# O-antigen ligase
# sucrose phosphorylase
# hypothetical protein
# carbohydrate ABC transporter permease
# sugar ABC transporter permease
# extracellular solute-binding protein
# alpha-galactosidase
# AraC family transcriptional regulator
# bifunctional biotin--[acetyl-CoA-carboxylase] ligase/biotin operon repressor BirA
# 23S rRNA (uracil(1939)-C(5))-methyltransferase RlmD
# recombination regulator RecX
# DUF402 domain-containing protein
# Rgg/GadR/MutR family transcriptional regulator
# helix-turn-helix transcriptional regulator
# class I SAM-dependent methyltransferase
# epoxyqueuosine reductase QueH
# chaperonin GroEL
# co-chaperone GroES
# single-stranded DNA-binding protein
# SDR family NAD(P)-dependent oxidoreductase
# YtpR family tRNA-binding protein
# thioredoxin family protein
# DUF4651 domain-containing protein
# hypothetical protein
# cell wall-binding protein
# hypothetical protein
# LytTR family DNA-binding domain-containing protein
# phosphatase PAP2 family protein
# DUF2200 domain-containing protein
# ATP-binding cassette domain-containing protein
# ABC transporter permease
# MarR family winged helix-turn-helix transcriptional regulator
# YebC/PmpR family DNA-binding transcriptional regulator
# cholesterol-dependent cytolysin pneumolysin
# hypothetical protein
# hypothetical protein
# DUF4231 domain-containing protein
# IS5 family transposase
# hypothetical protein
# hypothetical protein
# hypothetical protein
# hypothetical protein
# hypothetical protein
# hypothetical protein
# helix-turn-helix domain-containing protein
# N-acetylmuramoyl-L-alanine amidase LytA
# MATE family efflux transporter
# recombinase RecA
# competence/damage-inducible protein A
# LCP family protein
# GNAT family N-acetyltransferase
# tRNA (adenosine(37)-N6)-threonylcarbamoyltransferase complex ATPase subunit type 1 TsaE
# hypothetical protein
# helix-turn-helix transcriptional regulator
# PhrA family quorum-sensing system peptide
# lactococcin 972 family bacteriocin
# DUF1430 domain-containing protein
# ABC transporter ATP-binding protein
# hypothetical protein
# nucleoside-diphosphate kinase
# DNA-directed RNA polymerase subunit beta'
# DNA-directed RNA polymerase subunit beta
# hemolysin family protein
# DNA-entry nuclease EndA
# DNA-directed RNA polymerase subunit beta
# UDP-N-acetylglucosamine 1-carboxyvinyltransferase
# DUF1146 family protein
# SepM family pheromone-processing serine protease
# pantetheine-phosphate adenylyltransferase
# 16S rRNA (guanine(966)-N(2))-methyltransferase RsmD
# aspartate--ammonia ligase
# Bax inhibitor-1/YccA family protein
# RNA methyltransferase
# acylphosphatase
# membrane protein insertase YidC
# pyruvate formate-lyase-activating protein
# diaminopimelate decarboxylase
# pur operon repressor
# 3'-5' exoribonuclease YhaM family protein
# DNA recombination protein RmuC
# thiamine diphosphokinase
# ribulose-phosphate 3-epimerase
# ribosome small subunit-dependent GTPase A
# 16S rRNA (adenine(1518)-N(6)/adenine(1519)-N(6))- dimethyltransferase RsmA
# hypothetical protein
# ABC transporter ATP-binding protein
# bacteriocin-associated integral membrane family protein
# lactococcin 972 family bacteriocin
# helix-turn-helix transcriptional regulator
# ribonuclease M5
# TatD family hydrolase
# DUF1542 domain-containing protein
# 50S ribosomal protein L34
# pyridoxal phosphate-dependent aminotransferase
# hypothetical protein
# universal stress protein
# Cof-type HAD-IIB family hydrolase
# asparaginase
# catabolite control protein A
# response regulator transcription factor
# sensor histidine kinase
# ABC transporter permease
# ABC transporter ATP-binding protein
# hypothetical protein
# hypothetical protein
# sigma-70 family RNA polymerase sigma factor
# transcription termination/antitermination protein NusG
# preprotein translocase subunit SecE
# 50S ribosomal protein L33
# penicillin-binding protein PBP2A
# RluA family pseudouridine synthase
# type I glyceraldehyde-3-phosphate dehydrogenase
# FtsX-like permease family protein
# IS630 family transposase
# carboxylating nicotinate-nucleotide diphosphorylase
# SLC13 family permease
# transposase
# ABC transporter ATP-binding protein
# GntR family transcriptional regulator
# glycoside hydrolase family 1 protein
# PTS transporter subunit EIIC
# PTS sugar transporter subunit IIB
# PTS lactose/cellobiose transporter subunit IIA
# bifunctional acetaldehyde-CoA/alcohol dehydrogenase
# MORN repeat-containing protein
# low molecular weight protein-tyrosine-phosphatase
# preprotein translocase subunit YajC
# transketolase
# L-ascorbate 6-phosphate lactonase
# transcription antiterminator
# L-ribulose-5-phosphate 4-epimerase
# L-ribulose-5-phosphate 3-epimerase
# 3-keto-L-gulonate-6-phosphate decarboxylase UlaD
# PTS sugar transporter subunit IIA
# PTS sugar transporter subunit IIB
# PTS ascorbate transporter subunit IIC
# hypothetical protein
# RNA-binding cell elongation regulator Jag/EloR
# membrane protein insertase YidC
# ribonuclease P protein component
# hypothetical protein
# acetate kinase
# class I SAM-dependent methyltransferase
# methyltransferase domain-containing protein
# competence type IV pilus minor pilin ComGG
# competence type IV pilus minor pilin ComGF
# competence type IV pilus minor pilin ComGE
# competence type IV pilus minor pilin ComGD
# comG operon protein ComGC
# competence type IV pilus assembly protein ComGB
# competence type IV pilus ATPase ComGA
# DUF1033 family protein
# zinc-dependent alcohol dehydrogenase family protein
# N-acetylglucosamine-6-phosphate deacetylase
# acyltransferase family protein
# tRNA guanosine(34) transglycosylase Tgt
# DUF975 family protein
# pyroglutamyl-peptidase I
# DUF1304 domain-containing protein
# MarR family winged helix-turn-helix transcriptional regulator
# LysM domain-containing protein
# HAD family hydrolase
# MATE family efflux transporter
# threonine synthase
# glutamyl-tRNA synthetase
# hypothetical protein
# hypothetical protein
# hypothetical protein
# Rep protein
# DUF3173 family protein
# site-specific integrase
# HD domain-containing protein
# DUF6290 family protein
# metallophosphoesterase
# cytidine deaminase
# glutamate--tRNA ligase
# glucose-6-phosphate isomerase
# hypothetical protein
# gamma-glutamyl-gamma-aminobutyrate hydrolase family protein
# multidrug efflux ABC transporter subunit PatB
# transposase
# multidrug efflux ABC transporter subunit PatA
# DNA mismatch repair protein MutS
# arginine repressor
# arginine--tRNA ligase
# transposase
# cupin domain-containing protein
# response regulator transcription factor
# ATP-binding protein
# substrate-binding domain-containing protein
# phosphate ABC transporter permease subunit PstC
# phosphate ABC transporter permease PstA
# phosphate ABC transporter ATP-binding protein PstB
# phosphate signaling complex protein PhoU
# transposase
# hypothetical protein
# hypothetical protein
# NAD(P)H-dependent glycerol-3-phosphate dehydrogenase
# UTP--glucose-1-phosphate uridylyltransferase GalU
# rhomboid family intramembrane serine protease
# 5-formyltetrahydrofolate cyclo-ligase
# N-acetyldiaminopimelate deacetylase
# 2,3,4,5-tetrahydropyridine-2,6-dicarboxylate N-acetyltransferase
# DMT family transporter
# penicillin-binding protein PBP1B
# tyrosine--tRNA ligase
# heavy metal translocating P-type ATPase
# DUF6110 family protein
# putative RNA methyltransferase
# hypothetical protein
# hypothetical protein
# glycogen/starch/alpha-glucan family phosphorylase
# 4-alpha-glucanotransferase
# extracellular solute-binding protein
# sugar ABC transporter permease
# sugar ABC transporter permease
# DUF1189 domain-containing protein
# LacI family DNA-binding transcriptional regulator
# hypothetical protein
# YitT family protein
# aspartate--tRNA ligase
# hypothetical protein
# hypothetical protein
# type II CAAX endopeptidase family protein
# DUF3169 family protein
# hypothetical protein
# helix-turn-helix transcriptional regulator
# hypothetical protein
# hypothetical protein
# histidine--tRNA ligase
# transporter
# quorum-sensing system transcriptional regulator Rgg
# metal-sulfur cluster assembly factor
# hypothetical protein
# dihydroxy-acid dehydratase
# transketolase family protein
# transketolase
# PTS ascorbate transporter subunit IIC
# PTS sugar transporter subunit IIB
# BglG family transcription antiterminator
# SPFH domain-containing protein
# PTS ascorbate transporter subunit IIC
# 50S ribosomal protein L32
# 50S ribosomal protein L33
# leucine-rich repeat protein
# ATP-binding protein
# IS5 family transposase
# hypothetical protein
# hypothetical protein
# beta-N-acetylhexosaminidase
# ROK family protein
# alpha-mannosidase
# glycoside hydrolase family 125 protein
# GH92 family glycosyl hydrolase
# alpha-L-fucosidase
# arginine deiminase
# ornithine carbamoyltransferase
# carbamate kinase
# YfcC family protein
# dipeptidase
# ZmpA/ZmpB/ZmpC family metallo-endopeptidase
# YSIRK-type signal peptide-containing protein
# SPFH domain-containing protein
# iron-containing alcohol dehydrogenase
# L-fucose isomerase
# class II aldolase/adducin family protein
# glycoside hydrolase family 98 domain-containing protein
# alpha-galactosidase
# hypothetical protein
# alpha-L-fucosidase
# carbohydrate ABC transporter permease
# sugar ABC transporter permease
# ABC transporter substrate-binding protein
# rhamnulokinase family protein
# DeoR/GlpR family DNA-binding transcription regulator
# zinc ABC transporter substrate-binding lipoprotein AdcA
# metal ABC transporter permease
# metal ABC transporter ATP-binding protein
# zinc-dependent transcriptional regulator AdcR
# D-alanyl-lipoteichoic acid biosynthesis protein DltD
# D-alanine--poly(phosphoribitol) ligase subunit DltC
# D-alanyl-lipoteichoic acid biosynthesis protein DltB
# D-alanine--poly(phosphoribitol) ligase subunit DltA
# teichoic acid D-Ala incorporation-associated protein DltX
# ryptide export MFS transporter
# group II intron reverse transcriptase/maturase
# hypothetical protein
# hypothetical protein
# eukaryotic translation initiation factor 3 subunit E
# MIP/aquaporin family protein
# type 1 glycerol-3-phosphate oxidase
# glycerol kinase GlpK
# helix-turn-helix domain-containing protein
# Hsp33 family molecular chaperone HslO
# tRNA dihydrouridine synthase DusB
# IS3 family transposase
# ISL3 family transposase
# pneumococcal surface protein PspC, LPXTG-anchored form
# isoprenylcysteine carboxyl methyltransferase family protein
# two-component system sensor histidine kinase HK06
# two-component system response regulator RR06
# ATP-dependent Clp protease ATP-binding subunit
# CtsR family transcriptional regulator
# ABC transporter ATP-binding protein
# ABC transporter substrate-binding protein
# ABC transporter permease
# thiamine-binding protein
# choline binding-anchored murein hydrolase CbpD
# Veg family protein
# replicative DNA helicase
# 50S ribosomal protein L9
# DHH family phosphoesterase
# ribosome-associated translation inhibitor RaiA
# ComF family protein
# DEAD/DEAH box helicase
# YigZ family protein
# cysteine synthase A
# IS66 family transposase
# transposase
# IS66 family insertion sequence element accessory protein TnpB
# translation elongation factor Ts
# 30S ribosomal protein S2
# CHAP domain-containing protein
# rod shape-determining protein MreD
# rod shape-determining protein MreC
# energy-coupling factor transporter transmembrane protein EcfT
# energy-coupling factor transporter ATPase
# energy-coupling factor ABC transporter ATP-binding protein
# CDP-diacylglycerol--glycerol-3-phosphate 3-phosphatidyltransferase
# cytoskeleton protein RodZ
# pitrilysin family protein
# pitrilysin family protein
# S4 domain-containing protein YaaA
# DNA replication/repair protein RecF
# IMP dehydrogenase
# tryptophan--tRNA ligase
# ATP-binding cassette domain-containing protein
# YfhO family protein
# YhgE/Pip domain-containing protein
# TetR/AcrR family transcriptional regulator
# competence system response regulator transcription factor ComE
# competence system sensor histidine kinase ComD
# competence-stimulating peptide ComC
# 23S rRNA (pseudouridine(1915)-N(3))-methyltransferase RlmH
# S1C family serine protease
# ParB/RepB/Spo0J family partition protein
